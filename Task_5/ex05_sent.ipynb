# %% [markdown]
# # Importing Libraries

# %%
pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.8/dist-packages (2.2.0)

# %%
pip install better_profanity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: better_profanity in /usr/local/lib/python3.8/dist-packages (0.7.0)

# %%
# %pip install torch transformers datasets ipywidgets flaml[blendsearch,ray] #It is important to run this before installing datasets, due to compatibility issues
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.12.1+cu113)
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.8/dist-packages (2.7.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (7.7.1)
# Requirement already satisfied: flaml[blendsearch,ray] in /usr/local/lib/python3.8/dist-packages (1.0.14)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from datasets) (3.1.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (3.0.3)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.0.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets) (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (5.7.16)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: jinja2<=3.0.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.15.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.13.3)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2<=3.0.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.10.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from flaml[blendsearch,ray]) (1.7.3)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from flaml[blendsearch,ray]) (3.3.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from flaml[blendsearch,ray]) (1.0.2)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.8/dist-packages (from flaml[blendsearch,ray]) (0.90)
# Requirement already satisfied: ray[tune]~=1.13 in /usr/local/lib/python3.8/dist-packages (from flaml[blendsearch,ray]) (1.13.0)
# Requirement already satisfied: optuna==2.8.0 in /usr/local/lib/python3.8/dist-packages (from flaml[blendsearch,ray]) (2.8.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.8/dist-packages (from optuna==2.8.0->flaml[blendsearch,ray]) (6.7.0)
# Requirement already satisfied: cliff in /usr/local/lib/python3.8/dist-packages (from optuna==2.8.0->flaml[blendsearch,ray]) (4.1.0)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from optuna==2.8.0->flaml[blendsearch,ray]) (0.9.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from optuna==2.8.0->flaml[blendsearch,ray]) (1.4.44)
# Requirement already satisfied: alembic in /usr/local/lib/python3.8/dist-packages (from optuna==2.8.0->flaml[blendsearch,ray]) (1.8.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from lightgbm>=2.3.1->flaml[blendsearch,ray]) (0.38.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (20.17.0)
# Requirement already satisfied: click<=8.0.4,>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (7.1.2)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (1.43.0)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (3.19.6)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (1.0.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (0.8.10)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.8/dist-packages (from ray[tune]~=1.13->flaml[blendsearch,ray]) (2.5.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->flaml[blendsearch,ray]) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->flaml[blendsearch,ray]) (3.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy>=1.1.0->optuna==2.8.0->flaml[blendsearch,ray]) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from alembic->optuna==2.8.0->flaml[blendsearch,ray]) (4.13.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.8/dist-packages (from alembic->optuna==2.8.0->flaml[blendsearch,ray]) (1.2.4)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from cliff->optuna==2.8.0->flaml[blendsearch,ray]) (2.4.2)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from cliff->optuna==2.8.0->flaml[blendsearch,ray]) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from cliff->optuna==2.8.0->flaml[blendsearch,ray]) (3.5.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.8/dist-packages (from cliff->optuna==2.8.0->flaml[blendsearch,ray]) (4.1.1)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.8/dist-packages (from cmd2>=1.0.0->cliff->optuna==2.8.0->flaml[blendsearch,ray]) (1.8.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from stevedore>=2.0.1->cliff->optuna==2.8.0->flaml[blendsearch,ray]) (5.11.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.8/dist-packages (from virtualenv->ray[tune]~=1.13->flaml[blendsearch,ray]) (0.3.6)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv->ray[tune]~=1.13->flaml[blendsearch,ray]) (2.5.4)

# %%
#Importing all necessary packages and libraries

import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import emoji
import string
import random
import time
from nltk.corpus import stopwords
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
import torch
from tqdm import tqdm
import spacy
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from better_profanity import profanity
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
nlp = spacy.blank("en")
# %matplotlib inline

# %% [markdown]
# ### Define Path

# %%
MODEL_PATH = "/content/drive/My Drive/ML4NLP_Assignment5/model/" #That's where we will store the model 
DATA_PATH = "/content/drive/My Drive/ML4NLP_Assignment5/data/" #That's where we will store the data

# %% [markdown]
# ### Loading Dataset and Mounting Drive

# %%
# MOUNTING GOOGLE DRIVE

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# FUNCTION FOR LOADING DATA

def load_data(data_path, file_name, label=False):
    data_path = data_path + file_name
    df = pd.read_csv(data_path, on_bad_lines="skip", sep = "\t")
    X = df["Tweet"]
    y = df["Intensity Score"]
    return X, y

# %%
# LOADING DATA

X_train_raw, y_train_raw = load_data(DATA_PATH, "EI-reg-En-anger-train.txt")   #raw train dataset
X_test_raw, y_test_raw = load_data(DATA_PATH, "2018-EI-reg-En-anger-test-gold.txt") #raw test dataset

# %% [markdown]
# ### Data Cleaning & Tokenising

# %%
#Class for data cleaning and pre-processing 

class DataCleaning:
    def __init__(self):
        return
    # LOWERCASING
    def convert_lowercase(self, text):
        text = text.str.lower()
        return text
    # REMOVING HTML TAGS AND URLS
    def remove_html_url(self, text):
        re_html = re.compile("<.*?>")
        re_url = re.compile("https?://\S+|www\.\S+")
        re_user = re.compile("@\w+")
        wo_html_str = re_html.sub(r"", text)
        wo_url_str = re_url.sub("URL", wo_html_str)
        wo_user_str = re_user.sub("USER", wo_url_str)
        return wo_user_str
    # REPLACING SWEAR WORDS
    def replace_swear_words(self, text):
        text = profanity.censor(text, "-")
        return text
    # REMOVING PUNCTUATIONS & NUMBERS
    def remove_punctuation_number(self, text):
        text = text.str.replace('[{}]'.format(string.punctuation), "", regex=True)
        text = text.str.replace("\d+", "", regex=True)
        return text 
    # LEMMATISATION
    def lemmatisation(self, text):
        lemmatiser = WordNetLemmatizer()
        return lemmatiser.lemmatize(text)
    # TOKENISING
    def tokenise(self, text):
        tokenizer = TweetTokenizer()
        text = tokenizer.tokenize(text)
        return text
    # REPLACING EMOJIS TO TEXTS
    def demojise(self, text):
        text = [emoji.demojize(word)[1:-1] if emoji.demojize(word) != word else word for word in text]
        return text
    # REPLACING SWEAR WORDS TO ANGRY
    def replace_swear_word_to_angry(self, text):
        text = text.replace("----", "angry")
        return text
    # APPLYING ALL METHODS
    def clean(self, X):
        res = self.convert_lowercase(X)
        res = res.apply(self.remove_html_url)
        res = self.remove_punctuation_number(res)
        #res = res.apply(self.replace_swear_words) - we removed this step in the end due to better results without it 
        #res = res.apply(self.replace_swear_word_to_angry) - we removed this step in the end due to better results without it 
        res = res.apply(self.lemmatisation)
        res = res.apply(self.tokenise)
        res = res.apply(self.demojise)
        return res

# %%
#Applying the class defined above to clean and pre-process the data 
data_cleaning = DataCleaning()
X_train = data_cleaning.clean(X_train_raw) #applying to train dataset
X_test = data_cleaning.clean(X_test_raw) #applying to test dataset

# %% [markdown]
# # Save Pre-Processed Data

# %%
#Checking what type is our data 
type(X_train)
# Out:
# pandas.core.series.Series

# %%
#We convert it to pandas dataframe
X_train = X_train.to_frame()
X_test = X_test.to_frame()

# %%
#Just making sure what is the data format 
X_train.head()
# Out:
#                                                Tweet
# 0  [USER, USER, shut, up, hashtags, are, cool, of...
# 1  [it, makes, me, so, fucking, irate, jesus, nob...
# 2   [lol, adam, the, bull, with, his, fake, outrage]
# 3  [USER, passed, away, early, this, morning, in,...
# 4  [USER, lol, wow, i, was, gonna, say, really, h...

# %%
#We don't need to pre-process the labels 
y_train = y_train_raw
y_test = y_test_raw

# %%
#We convert the labels to dataframe
y_train = y_train.to_frame()
y_test = y_test.to_frame()

# %%
#Saving the pre-processed data
X_train.to_csv("/content/drive/My Drive/ML4NLP_Assignment5/X_train_2.csv")
X_test.to_csv("/content/drive/My Drive/ML4NLP_Assignment5/X_test_2.csv")
y_train.to_csv("/content/drive/My Drive/ML4NLP_Assignment5/y_train_2.csv")
y_test.to_csv("/content/drive/My Drive/ML4NLP_Assignment5/y_test_2.csv")

# %% [markdown]
# # Load the pre-processed data

# %%
#Loading the pre-processed data
X_train = pd.read_csv("/content/drive/My Drive/ML4NLP_Assignment5/X_train_2.csv")
X_test = pd.read_csv("/content/drive/My Drive/ML4NLP_Assignment5/X_test_2.csv")
y_train = pd.read_csv("/content/drive/My Drive/ML4NLP_Assignment5/y_train_2.csv")
y_test = pd.read_csv("/content/drive/My Drive/ML4NLP_Assignment5/y_test_2.csv")

# %%
X_train.drop(columns=["Unnamed: 0"])
# Out:
#                                                   Tweet
# 0     ['USER', 'USER', 'shut', 'up', 'hashtags', 'ar...
# 1     ['it', 'makes', 'me', 'so', 'fucking', 'irate'...
# 2     ['lol', 'adam', 'the', 'bull', 'with', 'his', ...
# 3     ['USER', 'passed', 'away', 'early', 'this', 'm...
# 4     ['USER', 'lol', 'wow', 'i', 'was', 'gonna', 's...
# ...                                                 ...
# 1696  ['got', 'a', 'tip', 'from', 'a', 'drunk', 'ube...
# 1697  ['USER', 'USER', 'USER', 'USER', 'fucker', 'bl...
# 1698                     ['USER', 'i', 'look', 'rabid']
# 1699  ['USER', 'im', 'not', 'surprised', 'i', 'would...
# 1700  ['USER', 'the', 'pout', 'tips', 'me', 'over', ...
#
# [1701 rows x 1 columns]

# %%
#We are dropping the extra column which is empty
X_train = X_train.drop(columns=["Unnamed: 0"])
X_test = X_test.drop(columns=["Unnamed: 0"])
y_train = y_train.drop(columns=["Unnamed: 0"])
y_test = y_test.drop(columns=["Unnamed: 0"])

# %% [markdown]
# # Data formating

# %% [markdown]
# Concatenate frames - We want to keep the tweets and labels in the same dataset object later

# %%
frames = [X_train, y_train]

# %%
train_data = pd.concat(frames, axis=1) #Concatenating tweets and labels for the train dataset in one dataframe

# %%
frames_test = [X_test, y_test]

# %%
test_data = pd.concat(frames_test, axis=1) #Concatenating tweets and labels for the test dataset in one dataframe

# %%
train_data.head()
# Out:
#                                                Tweet  Intensity Score
# 0  ['USER', 'USER', 'shut', 'up', 'hashtags', 'ar...            0.562
# 1  ['it', 'makes', 'me', 'so', 'fucking', 'irate'...            0.750
# 2  ['lol', 'adam', 'the', 'bull', 'with', 'his', ...            0.417
# 3  ['USER', 'passed', 'away', 'early', 'this', 'm...            0.354
# 4  ['USER', 'lol', 'wow', 'i', 'was', 'gonna', 's...            0.438

# %%
test_data.head()
# Out:
#                                                Tweet  Intensity Score
# 0  ['USER', 'i', 'know', 'you', 'mean', 'well', '...            0.734
# 1  ['let', 'go', 'of', 'resentment', 'it', 'will'...            0.422
# 2  ['no', 'im', 'not', 'depressed', 'because', 'o...            0.663
# 3  ['amarnathterrorattack', 'muslims', 'are', 'ki...            0.703
# 4  ['prepare', 'to', 'suffer', 'the', 'sting', 'o...            0.719

# %%
#Renaming columns in our train dataframe
train_data.rename(columns = {'Tweet':'text'}, inplace = True)

# %%
train_data.rename(columns = {'Intensity Score':'label'}, inplace = True)

# %%
#Checking the end result
train_data.head()
# Out:
#                                                 text  label
# 0  ['USER', 'USER', 'shut', 'up', 'hashtags', 'ar...  0.562
# 1  ['it', 'makes', 'me', 'so', 'fucking', 'irate'...  0.750
# 2  ['lol', 'adam', 'the', 'bull', 'with', 'his', ...  0.417
# 3  ['USER', 'passed', 'away', 'early', 'this', 'm...  0.354
# 4  ['USER', 'lol', 'wow', 'i', 'was', 'gonna', 's...  0.438

# %%
#Renaming columns in our test dataframe
test_data.rename(columns = {'Tweet':'text'}, inplace = True)
test_data.rename(columns = {'Intensity Score':'label'}, inplace = True)

# %%
#Checking the end result
test_data.head()
# Out:
#                                                 text  label
# 0  ['USER', 'i', 'know', 'you', 'mean', 'well', '...  0.734
# 1  ['let', 'go', 'of', 'resentment', 'it', 'will'...  0.422
# 2  ['no', 'im', 'not', 'depressed', 'because', 'o...  0.663
# 3  ['amarnathterrorattack', 'muslims', 'are', 'ki...  0.703
# 4  ['prepare', 'to', 'suffer', 'the', 'sting', 'o...  0.719

# %% [markdown]
# Splitting train_data into train_data and val_data for hyperparametres tuning

# %%
#first shuffle the data randomly 
shuffled_train = train_data.sample(frac=1)

# %%
len(shuffled_train)
# Out:
# 1701

# %%
# Splitting the train dataset into validation dataset and new train datatset
# approximately 15% of the initial train dataset will go to the validation dataset
train_data = shuffled_train[:1446]
val_data = shuffled_train[1446:]

# %%
#Importing more libraries and packages
import transformers
from datasets import Dataset,load_dataset, load_from_disk
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
#Getting the overview of the current training data format 
train_data.head()
# Out:
#                                                    text  label
# 1677  ['a', 'USER', 'not', 'turning', 'up', 'why', '...  0.688
# 635   ['firsttweetever', 'sippin', 'hotchocolate', '...  0.542
# 1049  ['im', 'just', 'doing', 'what', 'u', 'should',...  0.312
# 459   ['USER', 'USER', 'what', 'cant', 'you', 'grasp...  0.750
# 422   ['USER', 'hi', 'monica', 'i', 'write', 'regula...  0.375

# %%
train_data.loc[738]
# Out:
# text     ['ellie', 'just', 'gave', 'me', 'loads', 'of',...
# label                                                0.146
# Name: 738, dtype: object

# %% [markdown]
# Convert train, val, and test datasets from Dataframe to Dataset Object

# %%
# Coverting dataframes to dataset objects 
train_dataset = Dataset.from_pandas(train_data, preserve_index=False)
test_dataset = Dataset.from_pandas(test_data, preserve_index=False)
val_dataset = Dataset.from_pandas(val_data, preserve_index=False)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 1446
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 1002
# })

# %%
val_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 255
# })

# %%
val_dataset[2]
# Out:
# {'text': "['good', 'luck', 'to', 'all', 'furyhaney', 'players', 'playing', 'this', 'weekend', 'at', 'the', 'future', 'stars', 'showcase', 'in', 'frisco', 'tx', 'kgb', 'gtown', 'fury']",
#  'label': 0.396}

# %%
type(val_dataset[2]['text'])
# Out:
# str

# %% [markdown]
# Above we can see that what should be a list, is represented as a string in our Datasets object. Hence, we fix it below:

# %%
import ast

def fix_dataset(example):
  example['text'] = ast.literal_eval(example['text'])
  return example

# %%
val_dataset_fixed = val_dataset.map(fix_dataset)
# Out:
#   0%|          | 0/255 [00:00<?, ?ex/s]

# %%
val_dataset_fixed[2]
# Out:
# {'text': ['good',
#   'luck',
#   'to',
#   'all',
#   'furyhaney',
#   'players',
#   'playing',
#   'this',
#   'weekend',
#   'at',
#   'the',
#   'future',
#   'stars',
#   'showcase',
#   'in',
#   'frisco',
#   'tx',
#   'kgb',
#   'gtown',
#   'fury'],
#  'label': 0.396}

# %%
train_dataset_fixed = train_dataset.map(fix_dataset)
# Out:
#   0%|          | 0/1446 [00:00<?, ?ex/s]

# %%
test_dataset_fixed = test_dataset.map(fix_dataset)
# Out:
#   0%|          | 0/1002 [00:00<?, ?ex/s]

# %%
train_dataset_fixed[2]['text']
# Out:
# ['im',
#  'just',
#  'doing',
#  'what',
#  'u',
#  'should',
#  'b',
#  'doing',
#  'just',
#  'minding',
#  'my',
#  'business',
#  'and',
#  'grinding',
#  'relentless',
#  'USER']

# %% [markdown]
# De-tokenize.
# We already tokenized the dataset in the pre-processing step, but then we decided to use the HuggingFace Tokenizer instead. So we join the words again

# %%
#Function to join the words into one string per twit
def join_tweets(example):
  example['text'] = " ".join(example['text'])
  return example

# %%
#Applying this to the validation dataset
val_dataset_join = val_dataset_fixed.map(join_tweets)
# Out:
#   0%|          | 0/255 [00:00<?, ?ex/s]

# %%
val_dataset_join[2]
# Out:
# {'text': 'good luck to all furyhaney players playing this weekend at the future stars showcase in frisco tx kgb gtown fury',
#  'label': 0.396}

# %%
#Applying this to the train and test datasets
train_dataset_join = train_dataset_fixed.map(join_tweets)
test_dataset_join = test_dataset_fixed.map(join_tweets)
# Out:
#   0%|          | 0/1446 [00:00<?, ?ex/s]
#   0%|          | 0/1002 [00:00<?, ?ex/s]

# %%
train_dataset_join[2]
# Out:
# {'text': 'im just doing what u should b doing just minding my business and grinding relentless USER',
#  'label': 0.312}

# %%
lenghts_train = []

for a in range(len(train_dataset_join)):
  txt = train_dataset_join[a]['text']
  lenghts_train.append(len(txt))

# %%
#Check what is the length of the longest string/tweet
max(lenghts_train)
# Out:
# 268

# %% [markdown]
# Tokenize the pre-trained model

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

# %%
len(tokenizer)
# Out:
# 30522

# %%
#we want to padd all tweets to the length of the longest one
max_length = 268

# %%
#Now we tokenize the tweets again
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

tokenized_train_dataset = train_dataset_join.map(tokenize_function, batched=True)
tokenized_test_dataset = test_dataset_join.map(tokenize_function, batched=True)
tokenized_val_dataset = val_dataset_join.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
#Download the pre-trained model
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=1)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#Re-size the pre-trained model to the len of the tokenizer
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30522, 768, padding_idx=0)

# %%
from sklearn.metrics import mean_squared_error

# %%
import scipy.stats

# %%
#Define the function to compute the metrics 
from datasets import load_metric

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    rmse = mean_squared_error(labels, predictions, squared=False)
    r, p = scipy.stats.pearsonr(labels, predictions)
    return {"rmse": rmse, "pearsonr": r}

# %% [markdown]
# # First model

# %%
#Define the training args 
from transformers import TrainingArguments, Trainer
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_strategy="epoch",
                                  evaluation_strategy="epoch",
                                  per_device_train_batch_size=16,
                                  per_device_eval_batch_size=16,
                                  num_train_epochs=3,
                                  save_total_limit = 2,
                                  save_strategy = 'no',
                                  load_best_model_at_end=False
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics
)

# %%
#Train the first model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 321
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='321' max='321' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [321/321 01:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.014200</td>
#       <td>0.023599</td>
#       <td>0.153618</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.011300</td>
#       <td>0.018607</td>
#       <td>0.136407</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.006300</td>
#       <td>0.018800</td>
#       <td>0.137114</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=321, training_loss=0.010591309389964072, metrics={'train_runtime': 77.4272, 'train_samples_per_second': 65.907, 'train_steps_per_second': 4.146, 'total_flos': 675969080177664.0, 'train_loss': 0.010591309389964072, 'epoch': 3.0})

# %% [markdown]
# # Second model

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_squared_error, mean_absolute_error

# %%
import numpy as np

# %%
#Different version of the function to compute the metrics 
def compute_metrics_for_regression(eval_pred):
    logits, labels = eval_pred
    labels = labels.reshape(-1, 1)

    mse = mean_squared_error(labels, logits)
    rmse = mean_squared_error(labels, logits, squared=False)
    mae = mean_absolute_error(labels, logits)
    r2 = r2_score(labels, logits)
    smape = 1/len(labels) * np.sum(2 * np.abs(logits-labels) / (np.abs(labels) + np.abs(logits))*100)
    

    return {"mse": mse, "rmse": rmse, "mae": mae, "r2": r2, "smape": smape}

# %%
#Training arguments for the second model
from transformers import TrainingArguments, Trainer
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_strategy="epoch",
                                  evaluation_strategy="epoch",
                                  per_device_train_batch_size=16,
                                  per_device_eval_batch_size=16,
                                  num_train_epochs=3,
                                  save_total_limit = 2,
                                  save_strategy = 'no',
                                  load_best_model_at_end=False
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics_for_regression
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#Training the model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 321
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='321' max='321' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [321/321 01:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mse</th>
#       <th>Rmse</th>
#       <th>Mae</th>
#       <th>R2</th>
#       <th>Smape</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.007700</td>
#       <td>0.021191</td>
#       <td>0.021191</td>
#       <td>0.145572</td>
#       <td>0.114679</td>
#       <td>0.409509</td>
#       <td>24.137257</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.006100</td>
#       <td>0.019650</td>
#       <td>0.019650</td>
#       <td>0.140178</td>
#       <td>0.112058</td>
#       <td>0.452464</td>
#       <td>23.653032</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003900</td>
#       <td>0.018500</td>
#       <td>0.018500</td>
#       <td>0.136013</td>
#       <td>0.107576</td>
#       <td>0.484511</td>
#       <td>22.893147</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=321, training_loss=0.005878259274075707, metrics={'train_runtime': 77.9786, 'train_samples_per_second': 65.441, 'train_steps_per_second': 4.117, 'total_flos': 675969080177664.0, 'train_loss': 0.005878259274075707, 'epoch': 3.0})

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 16
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:04]
#     </div>
# {'eval_loss': 0.018499672412872314,
#  'eval_mse': 0.018499670550227165,
#  'eval_rmse': 0.13601349294185638,
#  'eval_mae': 0.10757619887590408,
#  'eval_r2': 0.484510977098937,
#  'eval_smape': 22.893147299151696,
#  'eval_runtime': 4.3911,
#  'eval_samples_per_second': 228.191,
#  'eval_steps_per_second': 14.347,
#  'epoch': 3.0}

# %% [markdown]
# # Third MODEL

# %%
#Arguments for the third model
from transformers import TrainingArguments, Trainer
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_strategy="epoch",
                                  evaluation_strategy="epoch",
                                  per_device_train_batch_size=64,
                                  per_device_eval_batch_size=20,
                                  weight_decay = 0.01, 
                                  learning_rate = 2e-5,
                                  num_train_epochs=10,
                                  save_total_limit = 10,
                                  save_strategy = 'epoch',
                                  load_best_model_at_end=True
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics_for_regression
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#Training the third model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 10
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 270
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='270' max='270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [270/270 04:14, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mse</th>
#       <th>Rmse</th>
#       <th>Mae</th>
#       <th>R2</th>
#       <th>Smape</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.003100</td>
#       <td>0.019845</td>
#       <td>0.019845</td>
#       <td>0.140873</td>
#       <td>0.112157</td>
#       <td>0.447020</td>
#       <td>23.871443</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003400</td>
#       <td>0.018579</td>
#       <td>0.018579</td>
#       <td>0.136306</td>
#       <td>0.107555</td>
#       <td>0.482293</td>
#       <td>22.882148</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003000</td>
#       <td>0.018530</td>
#       <td>0.018530</td>
#       <td>0.136125</td>
#       <td>0.107245</td>
#       <td>0.483669</td>
#       <td>22.812531</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.002600</td>
#       <td>0.018952</td>
#       <td>0.018952</td>
#       <td>0.137665</td>
#       <td>0.109006</td>
#       <td>0.471917</td>
#       <td>23.212203</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.002500</td>
#       <td>0.018704</td>
#       <td>0.018704</td>
#       <td>0.136764</td>
#       <td>0.108045</td>
#       <td>0.478806</td>
#       <td>23.025921</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.002400</td>
#       <td>0.019109</td>
#       <td>0.019109</td>
#       <td>0.138237</td>
#       <td>0.109671</td>
#       <td>0.467523</td>
#       <td>23.328195</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.002400</td>
#       <td>0.018377</td>
#       <td>0.018377</td>
#       <td>0.135560</td>
#       <td>0.107272</td>
#       <td>0.487943</td>
#       <td>22.883645</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.002200</td>
#       <td>0.018475</td>
#       <td>0.018475</td>
#       <td>0.135922</td>
#       <td>0.107592</td>
#       <td>0.485203</td>
#       <td>22.961912</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.002000</td>
#       <td>0.018683</td>
#       <td>0.018683</td>
#       <td>0.136684</td>
#       <td>0.108142</td>
#       <td>0.479413</td>
#       <td>23.060216</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.002100</td>
#       <td>0.018602</td>
#       <td>0.018602</td>
#       <td>0.136388</td>
#       <td>0.107823</td>
#       <td>0.481668</td>
#       <td>23.000450</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-27
# Configuration saved in test_trainer/checkpoint-27/config.json
# Model weights saved in test_trainer/checkpoint-27/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-54
# Configuration saved in test_trainer/checkpoint-54/config.json
# Model weights saved in test_trainer/checkpoint-54/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-81
# Configuration saved in test_trainer/checkpoint-81/config.json
# Model weights saved in test_trainer/checkpoint-81/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-108
# Configuration saved in test_trainer/checkpoint-108/config.json
# Model weights saved in test_trainer/checkpoint-108/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-135
# Configuration saved in test_trainer/checkpoint-135/config.json
# Model weights saved in test_trainer/checkpoint-135/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-162
# Configuration saved in test_trainer/checkpoint-162/config.json
# Model weights saved in test_trainer/checkpoint-162/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-189
# Configuration saved in test_trainer/checkpoint-189/config.json
# Model weights saved in test_trainer/checkpoint-189/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-216
# Configuration saved in test_trainer/checkpoint-216/config.json
# Model weights saved in test_trainer/checkpoint-216/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-243
# Configuration saved in test_trainer/checkpoint-243/config.json
# Model weights saved in test_trainer/checkpoint-243/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
# Saving model checkpoint to test_trainer/checkpoint-270
# Configuration saved in test_trainer/checkpoint-270/config.json
# Model weights saved in test_trainer/checkpoint-270/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from test_trainer/checkpoint-189 (score: 0.018376503139734268).
# TrainOutput(global_step=270, training_loss=0.0025765578641935632, metrics={'train_runtime': 254.7842, 'train_samples_per_second': 66.762, 'train_steps_per_second': 1.06, 'total_flos': 2253230267258880.0, 'train_loss': 0.0025765578641935632, 'epoch': 10.0})

# %%
#Evaluate the third model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
#     <div>
#
#       <progress value='51' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [51/51 00:04]
#     </div>
# {'eval_loss': 0.018376503139734268,
#  'eval_mse': 0.018376503139734268,
#  'eval_rmse': 0.13555996119976044,
#  'eval_mae': 0.107271708548069,
#  'eval_r2': 0.4879430731052734,
#  'eval_smape': 22.883644819735526,
#  'eval_runtime': 4.1423,
#  'eval_samples_per_second': 241.895,
#  'eval_steps_per_second': 12.312,
#  'epoch': 10.0}

# %% [markdown]
# # Fourth Model (trying FLAML)

# %%
from transformers import TrainingArguments, Trainer

# %%
MODEL_CHECKPOINT = "distilbert-base-uncased"

# %%
#Download the pre-trained model
model = AutoModelForSequenceClassification.from_pretrained(MODEL_CHECKPOINT, num_labels=1)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#Define training arguments 
args = TrainingArguments(
    output_dir='output',
    do_eval=True,
)

# %%
#Define the trainer 
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics_for_regression,
)

# %%
#Train the model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 639
#   Number of trainable parameters = 66954241
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='639' max='639' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [639/639 01:13, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.018600</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to output/checkpoint-500
# Configuration saved in output/checkpoint-500/config.json
# Model weights saved in output/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in output/checkpoint-500/tokenizer_config.json
# Special tokens file saved in output/checkpoint-500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=639, training_loss=0.016356775271873892, metrics={'train_runtime': 74.3096, 'train_samples_per_second': 68.672, 'train_steps_per_second': 8.599, 'total_flos': 675969080177664.0, 'train_loss': 0.016356775271873892, 'epoch': 3.0})

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 8
#     <div>
#
#       <progress value='126' max='126' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [126/126 00:04]
#     </div>
# {'eval_loss': 0.019569557160139084,
#  'eval_mse': 0.019569557160139084,
#  'eval_rmse': 0.13989123702049255,
#  'eval_mae': 0.11179779469966888,
#  'eval_r2': 0.45469886176708085,
#  'eval_smape': 23.760578452470057,
#  'eval_runtime': 4.3975,
#  'eval_samples_per_second': 227.854,
#  'eval_steps_per_second': 28.652,
#  'epoch': 3.0}

# %%
#Install flaml
# !pip install flaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flaml in /usr/local/lib/python3.7/dist-packages (1.0.14)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.21.6)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.7.3)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.7/dist-packages (from flaml) (0.90)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.0.2)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from flaml) (3.3.3)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from flaml) (1.3.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=2.3.1->flaml) (0.38.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->flaml) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->flaml) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->flaml) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->flaml) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->flaml) (1.2.0)

# %%
#Import the flaml
import flaml

# %%
#Define the function for the ray tuning 

def train_distilbert(config: dict):

    

    train_dataset, eval_dataset = tokenized_train_dataset, tokenized_val_dataset #Pass the train and evaluation sets for tuning

    model = AutoModelForSequenceClassification.from_pretrained(
        MODEL_CHECKPOINT, num_labels=1
    )

    def compute_metrics_for_regression(eval_pred): #Function to compute the metrics for evaluation 
        logits, labels = eval_pred
        labels = labels.reshape(-1, 1)

        mse = mean_squared_error(labels, logits)
        rmse = mean_squared_error(labels, logits, squared=False)
        mae = mean_absolute_error(labels, logits)
        r2 = r2_score(labels, logits)
        smape = 1/len(labels) * np.sum(2 * np.abs(logits-labels) / (np.abs(labels) + np.abs(logits))*100)

        return {"mse": mse, "rmse": rmse, "mae": mae, "r2": r2, "smape": smape}

    #Training args 
    training_args = TrainingArguments(
        output_dir='.',
        do_eval=False,
        disable_tqdm=True,
        logging_steps=20000,
        save_total_limit=0,
        **config,
    )
    #Trainer
    trainer = Trainer(
        model,
        training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        compute_metrics=compute_metrics_for_regression,
    )

    # train model
    trainer.train()

    # evaluate model
    eval_output = trainer.evaluate()

    # report the metric to optimize
    flaml.tune.report(
        r2=eval_output["eval_r2"],
    )

# %%
#Define the search space for ray tuning 
max_num_epoch = 64
search_space = {
        # You can mix constants with search space objects.
        "num_train_epochs": flaml.tune.loguniform(1, max_num_epoch),
        "learning_rate": flaml.tune.loguniform(1e-6, 1e-4),
        "adam_epsilon": flaml.tune.loguniform(1e-9, 1e-7),
        "adam_beta1": flaml.tune.uniform(0.8, 0.99),
        "adam_beta2": flaml.tune.loguniform(98e-2, 9999e-4),
}

# %%
# optimization objective
HP_METRIC, MODE = "r2", "max"

# resources
num_cpus = 0
num_gpus = 1

# constraints
num_samples = -1    # number of trials, -1 means unlimited
time_budget_s = 3600    # time budget in seconds

# %%
# !pip install pickle5

# %%
import pickle5 as pickle

# %%
#Ray tuning 
import time
import ray
start_time = time.time()
ray.shutdown()
ray.init(num_cpus=num_cpus, num_gpus=num_gpus)

print("Tuning started...")
analysis = flaml.tune.run(
    train_distilbert,
    search_alg=flaml.CFO(
        space=search_space,
        metric=HP_METRIC,
        mode=MODE,
        low_cost_partial_config={"num_train_epochs": 1}),
    # uncomment the following if scheduler = 'asha',
    # max_resource=max_num_epoch, min_resource=1,
    resources_per_trial={"gpu": num_gpus, "cpu": num_cpus},
    local_dir='logs/',
    num_samples=num_samples,
    time_budget_s=time_budget_s,
    use_ray=True,
)

ray.shutdown()
# Out:
# Tuning started...
# == Status ==<br>Current time: 2022-12-01 22:14:07 (running for 00:00:06.63)<br>Memory usage on this node: 5.2/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 1/infinite (1 RUNNING)<br><br>
# (train_distilbert pid=7468) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias']
# (train_distilbert pid=7468) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=7468) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=7468) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight', 'classifier.bias']
# (train_distilbert pid=7468) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=7468) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7468) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=7468)   FutureWarning,
# (train_distilbert pid=7468) ***** Running training *****
# (train_distilbert pid=7468)   Num examples = 1701
# (train_distilbert pid=7468)   Num Epochs = 1
# (train_distilbert pid=7468)   Instantaneous batch size per device = 8
# (train_distilbert pid=7468)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=7468)   Gradient Accumulation steps = 1
# (train_distilbert pid=7468)   Total optimization steps = 213
# (train_distilbert pid=7468)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-01 22:14:12 (running for 00:00:11.71)<br>Memory usage on this node: 6.1/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:14:17 (running for 00:00:16.72)<br>Memory usage on this node: 6.1/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:14:22 (running for 00:00:21.72)<br>Memory usage on this node: 6.1/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:14:27 (running for 00:00:26.73)<br>Memory usage on this node: 6.1/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:14:33 (running for 00:00:31.73)<br>Memory usage on this node: 6.1/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# (train_distilbert pid=7468)
# (train_distilbert pid=7468)
# (train_distilbert pid=7468) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=7468)
# (train_distilbert pid=7468)
# (train_distilbert pid=7468) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7468) ***** Running Evaluation *****
# (train_distilbert pid=7468)   Num examples = 1002
# (train_distilbert pid=7468)   Batch size = 8
# (train_distilbert pid=7468) {'train_runtime': 23.43, 'train_samples_per_second': 72.599, 'train_steps_per_second': 9.091, 'train_loss': 0.06773512576107688, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-01 22:14:38 (running for 00:00:36.74)<br>Memory usage on this node: 6.1/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# Trial train_distilbert_75886418 reported r2=0.04 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}.
# Trial train_distilbert_75886418 completed. Last result: r2=0.03501930286920463
# (train_distilbert pid=7468) {'eval_loss': 0.03463085740804672, 'eval_mse': 0.03463085740804672, 'eval_rmse': 0.18609367311000824, 'eval_mae': 0.15341486036777496, 'eval_r2': 0.03501930286920463, 'eval_smape': 31.362470371756483, 'eval_runtime': 4.2255, 'eval_samples_per_second': 237.131, 'eval_steps_per_second': 29.819, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-01 22:14:44 (running for 00:00:43.60)<br>Memory usage on this node: 5.2/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# (train_distilbert pid=7558) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.weight']
# (train_distilbert pid=7558) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=7558) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=7558) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# (train_distilbert pid=7558) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=7558) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7558) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=7558)   FutureWarning,
# (train_distilbert pid=7558) ***** Running training *****
# (train_distilbert pid=7558)   Num examples = 1701
# (train_distilbert pid=7558)   Num Epochs = 2
# (train_distilbert pid=7558)   Instantaneous batch size per device = 8
# (train_distilbert pid=7558)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=7558)   Gradient Accumulation steps = 1
# (train_distilbert pid=7558)   Total optimization steps = 308
# (train_distilbert pid=7558)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-01 22:14:49 (running for 00:00:48.61)<br>Memory usage on this node: 6.2/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:14:54 (running for 00:00:53.61)<br>Memory usage on this node: 6.2/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:14:59 (running for 00:00:58.62)<br>Memory usage on this node: 6.2/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:04 (running for 00:01:03.62)<br>Memory usage on this node: 6.2/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:09 (running for 00:01:08.63)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:14 (running for 00:01:13.63)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:19 (running for 00:01:18.64)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# (train_distilbert pid=7558) {'train_runtime': 33.4159, 'train_samples_per_second': 73.519, 'train_steps_per_second': 9.217, 'train_loss': 0.023007295348427513, 'epoch': 1.45}
# (train_distilbert pid=7558)
# (train_distilbert pid=7558)
# (train_distilbert pid=7558) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=7558)
# (train_distilbert pid=7558)
# (train_distilbert pid=7558) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7558) ***** Running Evaluation *****
# (train_distilbert pid=7558)   Num examples = 1002
# (train_distilbert pid=7558)   Batch size = 8
# == Status ==<br>Current time: 2022-12-01 22:15:24 (running for 00:01:23.64)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 75886418 with r2=0.03501930286920463 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# Trial train_distilbert_797cc10e reported r2=0.42 with parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}.
# Trial train_distilbert_797cc10e completed. Last result: r2=0.42094831344643224
# (train_distilbert pid=7558) {'eval_loss': 0.020780785009264946, 'eval_mse': 0.020780785009264946, 'eval_rmse': 0.14415541291236877, 'eval_mae': 0.11464690417051315, 'eval_r2': 0.42094831344643224, 'eval_smape': 24.019180389221553, 'eval_runtime': 4.2181, 'eval_samples_per_second': 237.548, 'eval_steps_per_second': 29.871, 'epoch': 1.45}
# == Status ==<br>Current time: 2022-12-01 22:15:31 (running for 00:01:30.56)<br>Memory usage on this node: 5.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# (train_distilbert pid=7656) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias']
# (train_distilbert pid=7656) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=7656) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=7656) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias']
# (train_distilbert pid=7656) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=7656) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7656) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=7656)   FutureWarning,
# (train_distilbert pid=7656) ***** Running training *****
# (train_distilbert pid=7656)   Num examples = 1701
# (train_distilbert pid=7656)   Num Epochs = 1
# (train_distilbert pid=7656)   Instantaneous batch size per device = 8
# (train_distilbert pid=7656)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=7656)   Gradient Accumulation steps = 1
# (train_distilbert pid=7656)   Total optimization steps = 213
# (train_distilbert pid=7656)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-01 22:15:36 (running for 00:01:35.56)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:41 (running for 00:01:40.57)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:46 (running for 00:01:45.58)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:51 (running for 00:01:50.58)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:15:56 (running for 00:01:55.59)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# (train_distilbert pid=7656) {'train_runtime': 23.5523, 'train_samples_per_second': 72.222, 'train_steps_per_second': 9.044, 'train_loss': 0.0513407568416685, 'epoch': 1.0}
# (train_distilbert pid=7656)
# (train_distilbert pid=7656)
# (train_distilbert pid=7656) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=7656)
# (train_distilbert pid=7656)
# (train_distilbert pid=7656) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7656) ***** Running Evaluation *****
# (train_distilbert pid=7656)   Num examples = 1002
# (train_distilbert pid=7656)   Batch size = 8
# == Status ==<br>Current time: 2022-12-01 22:16:01 (running for 00:02:00.59)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# Trial train_distilbert_8c1c4f3c reported r2=0.01 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.469662593007818e-06, 'adam_epsilon': 3.577276599136122e-08, 'adam_beta1': 0.839249940775602, 'adam_beta2': 0.9891306099839907}.
# Trial train_distilbert_8c1c4f3c completed. Last result: r2=0.005012244112677311
# (train_distilbert pid=7656) {'eval_loss': 0.0357077419757843, 'eval_mse': 0.0357077419757843, 'eval_rmse': 0.18896491825580597, 'eval_mae': 0.15632592141628265, 'eval_r2': 0.005012244112677311, 'eval_smape': 31.801034649451093, 'eval_runtime': 4.2213, 'eval_samples_per_second': 237.366, 'eval_steps_per_second': 29.848, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-01 22:16:08 (running for 00:02:07.59)<br>Memory usage on this node: 5.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# (train_distilbert pid=7747) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.weight']
# (train_distilbert pid=7747) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=7747) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=7747) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# (train_distilbert pid=7747) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=7747) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7747) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=7747)   FutureWarning,
# (train_distilbert pid=7747) ***** Running training *****
# (train_distilbert pid=7747)   Num examples = 1701
# (train_distilbert pid=7747)   Num Epochs = 2
# (train_distilbert pid=7747)   Instantaneous batch size per device = 8
# (train_distilbert pid=7747)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=7747)   Gradient Accumulation steps = 1
# (train_distilbert pid=7747)   Total optimization steps = 219
# (train_distilbert pid=7747)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-01 22:16:13 (running for 00:02:12.60)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:16:18 (running for 00:02:17.60)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:16:23 (running for 00:02:22.61)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:16:28 (running for 00:02:27.61)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:16:33 (running for 00:02:32.62)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# (train_distilbert pid=7747)
# (train_distilbert pid=7747)
# (train_distilbert pid=7747) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=7747)
# (train_distilbert pid=7747)
# (train_distilbert pid=7747) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7747) ***** Running Evaluation *****
# (train_distilbert pid=7747)   Num examples = 1002
# (train_distilbert pid=7747)   Batch size = 8
# (train_distilbert pid=7747) {'train_runtime': 24.3183, 'train_samples_per_second': 71.852, 'train_steps_per_second': 9.006, 'train_loss': 0.04933997376324379, 'epoch': 1.03}
# == Status ==<br>Current time: 2022-12-01 22:16:38 (running for 00:02:37.62)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# Trial train_distilbert_a81fc376 reported r2=0.01 with parameters={'num_train_epochs': 1.027230096840913, 'learning_rate': 1.669208744541454e-06, 'adam_epsilon': 1.0852050441286482e-08, 'adam_beta1': 0.8986175660460669, 'adam_beta2': 0.9854524345419025}.
# Trial train_distilbert_a81fc376 completed. Last result: r2=0.008964617345048276
# (train_distilbert pid=7747) {'eval_loss': 0.03556589409708977, 'eval_mse': 0.035565901547670364, 'eval_rmse': 0.18858924508094788, 'eval_mae': 0.156161829829216, 'eval_r2': 0.008964617345048276, 'eval_smape': 31.816616766467064, 'eval_runtime': 4.2488, 'eval_samples_per_second': 235.829, 'eval_steps_per_second': 29.655, 'epoch': 1.03}
# == Status ==<br>Current time: 2022-12-01 22:16:46 (running for 00:02:45.57)<br>Memory usage on this node: 5.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# (train_distilbert pid=7839) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias']
# (train_distilbert pid=7839) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=7839) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=7839) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# (train_distilbert pid=7839) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=7839) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7839) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=7839)   FutureWarning,
# (train_distilbert pid=7839) ***** Running training *****
# (train_distilbert pid=7839)   Num examples = 1701
# (train_distilbert pid=7839)   Num Epochs = 1
# (train_distilbert pid=7839)   Instantaneous batch size per device = 8
# (train_distilbert pid=7839)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=7839)   Gradient Accumulation steps = 1
# (train_distilbert pid=7839)   Total optimization steps = 213
# (train_distilbert pid=7839)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-01 22:16:51 (running for 00:02:50.58)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:16:56 (running for 00:02:55.58)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:17:01 (running for 00:03:00.59)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:17:06 (running for 00:03:05.60)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:17:11 (running for 00:03:10.60)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# (train_distilbert pid=7839) {'train_runtime': 23.6504, 'train_samples_per_second': 71.923, 'train_steps_per_second': 9.006, 'train_loss': 0.05850101972409817, 'epoch': 1.0}
# (train_distilbert pid=7839)
# (train_distilbert pid=7839)
# (train_distilbert pid=7839) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=7839)
# (train_distilbert pid=7839)
# (train_distilbert pid=7839) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7839) ***** Running Evaluation *****
# (train_distilbert pid=7839)   Num examples = 1002
# (train_distilbert pid=7839)   Batch size = 8
# == Status ==<br>Current time: 2022-12-01 22:17:16 (running for 00:03:15.61)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# (train_distilbert pid=7839) {'eval_loss': 0.035196490585803986, 'eval_mse': 0.035196490585803986, 'eval_rmse': 0.1876072734594345, 'eval_mae': 0.15493591129779816, 'eval_r2': 0.0192580430217133, 'eval_smape': 31.622261336701595, 'eval_runtime': 4.235, 'eval_samples_per_second': 236.598, 'eval_steps_per_second': 29.752, 'epoch': 1.0}
# Trial train_distilbert_be2eb96a reported r2=0.02 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.4140209531361843e-06, 'adam_epsilon': 1.7536031374142777e-08, 'adam_beta1': 0.8920528630228418, 'adam_beta2': 0.9872627816010259}.
# Trial train_distilbert_be2eb96a completed. Last result: r2=0.0192580430217133
# == Status ==<br>Current time: 2022-12-01 22:17:23 (running for 00:03:22.64)<br>Memory usage on this node: 5.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# (train_distilbert pid=7932) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.bias']
# (train_distilbert pid=7932) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=7932) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=7932) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'pre_classifier.weight', 'classifier.bias', 'classifier.weight']
# (train_distilbert pid=7932) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=7932) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=7932) /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=7932)   FutureWarning,
# (train_distilbert pid=7932) ***** Running training *****
# (train_distilbert pid=7932)   Num examples = 1701
# (train_distilbert pid=7932)   Num Epochs = 3
# (train_distilbert pid=7932)   Instantaneous batch size per device = 8
# (train_distilbert pid=7932)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=7932)   Gradient Accumulation steps = 1
# (train_distilbert pid=7932)   Total optimization steps = 459
# (train_distilbert pid=7932)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-01 22:17:28 (running for 00:03:27.65)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:17:33 (running for 00:03:32.65)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:17:38 (running for 00:03:37.66)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 22:17:43 (running for 00:03:42.66)<br>Memory usage on this node: 6.0/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 797cc10e with r2=0.42094831344643224 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.2432004833442285e-05, 'adam_epsilon': 3.4102391893542775e-09, 'adam_beta1': 0.943680029695067, 'adam_beta2': 0.9802681933780513}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# ...
# == Status ==<br>Current time: 2022-12-01 23:13:31 (running for 00:59:30.62)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# (train_distilbert pid=10665) Saving model checkpoint to ./checkpoint-3000
# (train_distilbert pid=10665) Configuration saved in ./checkpoint-3000/config.json
# (train_distilbert pid=10665) Model weights saved in ./checkpoint-3000/pytorch_model.bin
# (train_distilbert pid=10665) tokenizer config file saved in ./checkpoint-3000/tokenizer_config.json
# (train_distilbert pid=10665) Special tokens file saved in ./checkpoint-3000/special_tokens_map.json
# == Status ==<br>Current time: 2022-12-01 23:13:36 (running for 00:59:35.62)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 23:13:41 (running for 00:59:40.63)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 23:13:46 (running for 00:59:45.64)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 23:13:51 (running for 00:59:50.65)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 23:13:56 (running for 00:59:55.65)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 23:14:01 (running for 01:00:00.66)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (1 PENDING, 1 RUNNING, 24 TERMINATED)<br><br>
# 2022-12-01 23:14:06,936	INFO stopper.py:364 -- Reached timeout of 3600 seconds. Stopping all trials.
# == Status ==<br>Current time: 2022-12-01 23:14:06 (running for 01:00:05.67)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (26 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-01 23:14:06 (running for 01:00:05.71)<br>Memory usage on this node: 6.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 0/1 GPUs, 0.0/49.59 GiB heap, 0.0/24.8 GiB objects<br>Current best trial: 1250f7d4 with r2=0.46146595422366776 and parameters={'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}<br>Result logdir: /content/logs/train_distilbert_2022-12-01_22-14-01<br>Number of trials: 26/infinite (26 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc             </th><th style="text-align: right;">  adam_beta1</th><th style="text-align: right;">  adam_beta2</th><th style="text-align: right;">  adam_epsilon</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  num_train_epochs</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">        r2</th></tr>
# </thead>
# <tbody>
# <tr><td>train_distilbert_75886418</td><td>TERMINATED</td><td>172.28.0.2:7468 </td><td style="text-align: right;">    0.868934</td><td style="text-align: right;">    0.98729 </td><td style="text-align: right;">   1.9703e-08 </td><td style="text-align: right;">    1.56626e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     1</td><td style="text-align: right;">         30.3793</td><td style="text-align: right;">0.0350193 </td></tr>
# <tr><td>train_distilbert_797cc10e</td><td>TERMINATED</td><td>172.28.0.2:7558 </td><td style="text-align: right;">    0.94368 </td><td style="text-align: right;">    0.980268</td><td style="text-align: right;">   3.41024e-09</td><td style="text-align: right;">    3.2432e-05 </td><td style="text-align: right;">           1.44427</td><td style="text-align: right;">     1</td><td style="text-align: right;">         40.3436</td><td style="text-align: right;">0.420948  </td></tr>
# <tr><td>train_distilbert_8c1c4f3c</td><td>TERMINATED</td><td>172.28.0.2:7656 </td><td style="text-align: right;">    0.83925 </td><td style="text-align: right;">    0.989131</td><td style="text-align: right;">   3.57728e-08</td><td style="text-align: right;">    1.46966e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     1</td><td style="text-align: right;">         30.4707</td><td style="text-align: right;">0.00501224</td></tr>
# <tr><td>train_distilbert_a81fc376</td><td>TERMINATED</td><td>172.28.0.2:7747 </td><td style="text-align: right;">    0.898618</td><td style="text-align: right;">    0.985452</td><td style="text-align: right;">   1.08521e-08</td><td style="text-align: right;">    1.66921e-06</td><td style="text-align: right;">           1.02723</td><td style="text-align: right;">     1</td><td style="text-align: right;">         31.2992</td><td style="text-align: right;">0.00896462</td></tr>
# <tr><td>train_distilbert_be2eb96a</td><td>TERMINATED</td><td>172.28.0.2:7839 </td><td style="text-align: right;">    0.892053</td><td style="text-align: right;">    0.987263</td><td style="text-align: right;">   1.7536e-08 </td><td style="text-align: right;">    1.41402e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     1</td><td style="text-align: right;">         30.5941</td><td style="text-align: right;">0.019258  </td></tr>
# <tr><td>train_distilbert_d4d3bcce</td><td>TERMINATED</td><td>172.28.0.2:7932 </td><td style="text-align: right;">    0.845815</td><td style="text-align: right;">    0.987317</td><td style="text-align: right;">   2.21377e-08</td><td style="text-align: right;">    1.73489e-06</td><td style="text-align: right;">           2.15443</td><td style="text-align: right;">     1</td><td style="text-align: right;">         56.6846</td><td style="text-align: right;">0.104871  </td></tr>
# <tr><td>train_distilbert_eae45e74</td><td>TERMINATED</td><td>172.28.0.2:8035 </td><td style="text-align: right;">    0.856788</td><td style="text-align: right;">    0.988564</td><td style="text-align: right;">   3.92079e-08</td><td style="text-align: right;">    2.81634e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     1</td><td style="text-align: right;">         30.5621</td><td style="text-align: right;">0.0509921 </td></tr>
# <tr><td>train_distilbert_110ae6f4</td><td>TERMINATED</td><td>172.28.0.2:8128 </td><td style="text-align: right;">    0.857961</td><td style="text-align: right;">    0.986044</td><td style="text-align: right;">   1.11248e-08</td><td style="text-align: right;">    1e-06      </td><td style="text-align: right;">           2.72935</td><td style="text-align: right;">     1</td><td style="text-align: right;">         71.3863</td><td style="text-align: right;">0.047188  </td></tr>
# <tr><td>train_distilbert_27172e26</td><td>TERMINATED</td><td>172.28.0.2:8238 </td><td style="text-align: right;">    0.806751</td><td style="text-align: right;">    0.987522</td><td style="text-align: right;">   2.67955e-08</td><td style="text-align: right;">    1.95709e-06</td><td style="text-align: right;">           1.59538</td><td style="text-align: right;">     1</td><td style="text-align: right;">         44.2964</td><td style="text-align: right;">0.143462  </td></tr>
# <tr><td>train_distilbert_55961c9e</td><td>TERMINATED</td><td>172.28.0.2:8336 </td><td style="text-align: right;">    0.884879</td><td style="text-align: right;">    0.987112</td><td style="text-align: right;">   1.82896e-08</td><td style="text-align: right;">    1.53792e-06</td><td style="text-align: right;">           2.90939</td><td style="text-align: right;">     1</td><td style="text-align: right;">         75.5793</td><td style="text-align: right;">0.181381  </td></tr>
# <tr><td>train_distilbert_776b24c2</td><td>TERMINATED</td><td>172.28.0.2:8448 </td><td style="text-align: right;">    0.8     </td><td style="text-align: right;">    0.985267</td><td style="text-align: right;">   2.27809e-08</td><td style="text-align: right;">    1.37799e-06</td><td style="text-align: right;">           1.13548</td><td style="text-align: right;">     1</td><td style="text-align: right;">         33.6179</td><td style="text-align: right;">0.0359436 </td></tr>
# <tr><td>train_distilbert_a4dfcc14</td><td>TERMINATED</td><td>172.28.0.2:8543 </td><td style="text-align: right;">    0.913908</td><td style="text-align: right;">    0.989371</td><td style="text-align: right;">   2.15127e-08</td><td style="text-align: right;">    2.18424e-06</td><td style="text-align: right;">           4.08775</td><td style="text-align: right;">     1</td><td style="text-align: right;">        102.468 </td><td style="text-align: right;">0.335473  </td></tr>
# <tr><td>train_distilbert_c0bc9a20</td><td>TERMINATED</td><td>172.28.0.2:8671 </td><td style="text-align: right;">    0.870562</td><td style="text-align: right;">    0.989361</td><td style="text-align: right;">   3.45899e-08</td><td style="text-align: right;">    2.48965e-06</td><td style="text-align: right;">           3.40243</td><td style="text-align: right;">     1</td><td style="text-align: right;">         86.7904</td><td style="text-align: right;">0.370432  </td></tr>
# <tr><td>train_distilbert_fe496102</td><td>TERMINATED</td><td>172.28.0.2:8789 </td><td style="text-align: right;">    0.928224</td><td style="text-align: right;">    0.987122</td><td style="text-align: right;">   1.13749e-08</td><td style="text-align: right;">    1.34926e-06</td><td style="text-align: right;">           3.4954 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         88.879 </td><td style="text-align: right;">0.170174  </td></tr>
# <tr><td>train_distilbert_3650b596</td><td>TERMINATED</td><td>172.28.0.2:8898 </td><td style="text-align: right;">    0.845786</td><td style="text-align: right;"
# (train_distilbert pid=10665) Saving model checkpoint to ./checkpoint-3500
# (train_distilbert pid=10665) Configuration saved in ./checkpoint-3500/config.json
# (train_distilbert pid=10665) Model weights saved in ./checkpoint-3500/pytorch_model.bin
# (train_distilbert pid=10665) tokenizer config file saved in ./checkpoint-3500/tokenizer_config.json
# (train_distilbert pid=10665) Special tokens file saved in ./checkpoint-3500/special_tokens_map.json
# (train_distilbert pid=10665) Saving model checkpoint to ./checkpoint-4000
# (train_distilbert pid=10665) Configuration saved in ./checkpoint-4000/config.json
# (train_distilbert pid=10665) Model weights saved in ./checkpoint-4000/pytorch_model.bin
# (train_distilbert pid=10665) tokenizer config file saved in ./checkpoint-4000/tokenizer_config.json
# (train_distilbert pid=10665) Special tokens file saved in ./checkpoint-4000/special_tokens_map.json
# (train_distilbert pid=10665)
# (train_distilbert pid=10665)
# (train_distilbert pid=10665) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=10665)
# (train_distilbert pid=10665)
# (train_distilbert pid=10665) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=10665) ***** Running Evaluation *****
# (train_distilbert pid=10665)   Num examples = 1002
# (train_distilbert pid=10665)   Batch size = 8
# (train_distilbert pid=10665) {'train_runtime': 474.7559, 'train_samples_per_second': 72.816, 'train_steps_per_second': 9.118, 'train_loss': 0.010420797713278182, 'epoch': 20.32}
# 2022-12-01 23:16:03,226	INFO tune.py:748 -- Total run time: 3722.07 seconds (3605.67 seconds for the tuning loop).
# (train_distilbert pid=10665) {'eval_loss': 0.020890725776553154, 'eval_mse': 0.020890725776553154, 'eval_rmse': 0.14453624188899994, 'eval_mae': 0.11490651220083237, 'eval_r2': 0.4178848508485151, 'eval_smape': 24.54094545284431, 'eval_runtime': 4.2376, 'eval_samples_per_second': 236.453, 'eval_steps_per_second': 29.734, 'epoch': 20.32}

# %%
#Get the results of hyperparameters optimization 
best_trial = analysis.get_best_trial(HP_METRIC, MODE, "all")
metric = best_trial.metric_analysis[HP_METRIC][MODE]
print(f"n_trials={len(analysis.trials)}")
print(f"time={time.time()-start_time}")
print(f"Best model eval {HP_METRIC}: {metric:.4f}")
print(f"Best model parameters: {best_trial.config}")
# Out:
# n_trials=26
# time=3748.902177810669
# Best model eval r2: 0.4615
# Best model parameters: {'num_train_epochs': 14.90289944900019, 'learning_rate': 4.278615732972273e-06, 'adam_epsilon': 6.900956598306757e-08, 'adam_beta1': 0.841736350312499, 'adam_beta2': 0.9938714514369775}

# %%
model = AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=1)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.24.0",
#   "vocab_size": 30522
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/pytorch_model.bin
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30522, 768, padding_idx=0)

# %%
#Now use the best hyperparameters found to train the model
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_steps=20000,
                                  per_device_train_batch_size=64,
                                  per_device_eval_batch_size=20,
                                  learning_rate = 4.278615732972273e-06,
                                  adam_epsilon = 6.900956598306757e-08,
                                  adam_beta1 = 0.841736350312499,
                                  adam_beta2 = 0.9938714514369775,
                                  num_train_epochs=15,
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics_for_regression
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#Train the model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 15
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 405
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='405' max='405' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [405/405 04:46, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=405, training_loss=0.010689811942018108, metrics={'train_runtime': 287.6483, 'train_samples_per_second': 88.702, 'train_steps_per_second': 1.408, 'total_flos': 3379845400888320.0, 'train_loss': 0.010689811942018108, 'epoch': 15.0})

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 20
#     <div>
#
#       <progress value='51' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [51/51 00:03]
#     </div>
# {'eval_loss': 0.02048257365822792,
#  'eval_mse': 0.02048257552087307,
#  'eval_rmse': 0.14311735332012177,
#  'eval_mae': 0.11232398450374603,
#  'eval_r2': 0.4292578633151708,
#  'eval_smape': 23.861486012350298,
#  'eval_runtime': 4.0928,
#  'eval_samples_per_second': 244.819,
#  'eval_steps_per_second': 12.461,
#  'epoch': 15.0}

# %% [markdown]
# # Fifth model

# %%
#Trying with different training arguments 
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_steps=20000,
                                  #per_device_train_batch_size=64,
                                  #per_device_eval_batch_size=20,
                                  learning_rate = 4.278615732972273e-06,
                                  adam_epsilon = 6.900956598306757e-08,
                                  adam_beta1 = 0.841736350312499,
                                  adam_beta2 = 0.9938714514369775,
                                  num_train_epochs=50,
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics_for_regression
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#Train the model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 50
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10650
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='10650' max='10650' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10650/10650 20:20, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to test_trainer/checkpoint-500
# Configuration saved in test_trainer/checkpoint-500/config.json
# Model weights saved in test_trainer/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-1000
# Configuration saved in test_trainer/checkpoint-1000/config.json
# Model weights saved in test_trainer/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-1500
# Configuration saved in test_trainer/checkpoint-1500/config.json
# Model weights saved in test_trainer/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-2000
# Configuration saved in test_trainer/checkpoint-2000/config.json
# Model weights saved in test_trainer/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-2500
# Configuration saved in test_trainer/checkpoint-2500/config.json
# Model weights saved in test_trainer/checkpoint-2500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-3000
# Configuration saved in test_trainer/checkpoint-3000/config.json
# Model weights saved in test_trainer/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-3500
# Configuration saved in test_trainer/checkpoint-3500/config.json
# Model weights saved in test_trainer/checkpoint-3500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-4000
# Configuration saved in test_trainer/checkpoint-4000/config.json
# Model weights saved in test_trainer/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-4500
# Configuration saved in test_trainer/checkpoint-4500/config.json
# Model weights saved in test_trainer/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-5000
# Configuration saved in test_trainer/checkpoint-5000/config.json
# Model weights saved in test_trainer/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-5500
# Configuration saved in test_trainer/checkpoint-5500/config.json
# Model weights saved in test_trainer/checkpoint-5500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-6000
# Configuration saved in test_trainer/checkpoint-6000/config.json
# Model weights saved in test_trainer/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-6500
# Configuration saved in test_trainer/checkpoint-6500/config.json
# Model weights saved in test_trainer/checkpoint-6500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-7000
# Configuration saved in test_trainer/checkpoint-7000/config.json
# Model weights saved in test_trainer/checkpoint-7000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-7500
# Configuration saved in test_trainer/checkpoint-7500/config.json
# Model weights saved in test_trainer/checkpoint-7500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-8000
# Configuration saved in test_trainer/checkpoint-8000/config.json
# Model weights saved in test_trainer/checkpoint-8000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-8500
# Configuration saved in test_trainer/checkpoint-8500/config.json
# Model weights saved in test_trainer/checkpoint-8500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-9000
# Configuration saved in test_trainer/checkpoint-9000/config.json
# Model weights saved in test_trainer/checkpoint-9000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-9500
# Configuration saved in test_trainer/checkpoint-9500/config.json
# Model weights saved in test_trainer/checkpoint-9500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-10000
# Configuration saved in test_trainer/checkpoint-10000/config.json
# Model weights saved in test_trainer/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-10500
# Configuration saved in test_trainer/checkpoint-10500/config.json
# Model weights saved in test_trainer/checkpoint-10500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=10650, training_loss=0.0033621011653416594, metrics={'train_runtime': 1220.3216, 'train_samples_per_second': 69.695, 'train_steps_per_second': 8.727, 'total_flos': 1.12661513362944e+16, 'train_loss': 0.0033621011653416594, 'epoch': 50.0})

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 8
#     <div>
#
#       <progress value='126' max='126' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [126/126 00:04]
#     </div>
# {'eval_loss': 0.020279884338378906,
#  'eval_mse': 0.020279884338378906,
#  'eval_rmse': 0.14240746200084686,
#  'eval_mae': 0.11204035580158234,
#  'eval_r2': 0.4349057738233796,
#  'eval_smape': 23.816269804141715,
#  'eval_runtime': 4.446,
#  'eval_samples_per_second': 225.371,
#  'eval_steps_per_second': 28.34,
#  'epoch': 50.0}

# %% [markdown]
# # New ray search and Sixth model

# %%
from transformers import TrainingArguments, Trainer

# %%
MODEL_CHECKPOINT = "distilbert-base-uncased"

# %%
#Download the pre-trained model
model = AutoModelForSequenceClassification.from_pretrained(MODEL_CHECKPOINT, num_labels=1)
# Out:
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.bias', 'classifier.weight', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#Re-size to the length of the tokenizer 
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30522, 768, padding_idx=0)

# %%
#Traing args
args = TrainingArguments(
    output_dir='output',
    do_eval=True,
)

# %%
#Define the trainer 
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics_for_regression,
)

# %%
#Train the model
trainer.train()

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 8
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='126' max='126' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [126/126 00:04]
#     </div>
# {'eval_loss': 0.4004843831062317,
#  'eval_mse': 0.4004843831062317,
#  'eval_rmse': 0.6328383684158325,
#  'eval_mae': 0.6030510663986206,
#  'eval_r2': -10.159403175849627,
#  'eval_smape': 199.99999999999997,
#  'eval_runtime': 7.6485,
#  'eval_samples_per_second': 131.005,
#  'eval_steps_per_second': 16.474}

# %%
# !pip install flaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flaml in /usr/local/lib/python3.8/dist-packages (1.0.14)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.8/dist-packages (from flaml) (0.90)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.0.2)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.21.6)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.7.3)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from flaml) (3.3.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from lightgbm>=2.3.1->flaml) (0.38.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->flaml) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->flaml) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->flaml) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->flaml) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->flaml) (1.2.0)

# %%
import flaml

# %%
def train_distilbert(config: dict): #Preparing the function for another tuning 

    

    train_dataset, eval_dataset = tokenized_train_dataset, tokenized_val_dataset

    model = AutoModelForSequenceClassification.from_pretrained(
        MODEL_CHECKPOINT, num_labels=1
    )
    model.resize_token_embeddings(len(tokenizer))

    

    def compute_metrics_for_regression(eval_pred):
        logits, labels = eval_pred
        labels = labels.reshape(-1, 1)

        mse = mean_squared_error(labels, logits)
        rmse = mean_squared_error(labels, logits, squared=False)
        mae = mean_absolute_error(labels, logits)
        r2 = r2_score(labels, logits)
        smape = 1/len(labels) * np.sum(2 * np.abs(logits-labels) / (np.abs(labels) + np.abs(logits))*100)

        return {"mse": mse, "rmse": rmse, "mae": mae, "r2": r2, "smape": smape}


    training_args = TrainingArguments(
        output_dir='.',
        do_eval=False,
        disable_tqdm=True,
        logging_steps=20000,
        save_total_limit=0,
        **config,
    )

    trainer = Trainer(
        model,
        training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        compute_metrics=compute_metrics_for_regression,
    )

    # train model
    trainer.train()

    # evaluate model
    eval_output = trainer.evaluate()

    # report the metric to optimize
    flaml.tune.report(
        r2=eval_output["eval_r2"],
    )

# %%
############ Version 2 ########################
#Different search space for hyperparameters tuning

max_num_epoch = 64
search_space = {
        # You can mix constants with search space objects.
        "num_train_epochs": flaml.tune.loguniform(1, max_num_epoch),
        "learning_rate": flaml.tune.loguniform(1e-6, 1e-4),
        "adam_epsilon": flaml.tune.loguniform(1e-9, 1e-7),
        "adam_beta1": flaml.tune.uniform(0.8, 0.99),
        "adam_beta2": flaml.tune.loguniform(98e-2, 9999e-4),
        "weight_decay": flaml.tune.uniform(0.0, 0.3),
        
}

# %%
# optimization objective
HP_METRIC, MODE = "r2", "max"

# resources
num_cpus = 0
num_gpus = 1

# constraints
num_samples = -1    # number of trials, -1 means unlimited
time_budget_s = 3600    # time budget in seconds

# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 15.8 MB/s
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp38-cp38-linux_x86_64.whl size=236289 sha256=2f125c921bff129c58703213e7e09403daec129c23a997f1f3c2bf7eb4eb8261
#   Stored in directory: /root/.cache/pip/wheels/25/d4/61/dbd8edd1a0d656be7b4267c85db3b61951eb60016a0154a122
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
import pickle5 as pickle

# %%
#Another ray hyperparameters tuning
import time
import ray
start_time = time.time()
ray.shutdown()
ray.init(num_cpus=num_cpus, num_gpus=num_gpus)

print("Tuning started...")
analysis = flaml.tune.run(
    train_distilbert,
    search_alg=flaml.CFO(
        space=search_space,
        metric=HP_METRIC,
        mode=MODE,
        low_cost_partial_config={"num_train_epochs": 1}),
    # uncomment the following if scheduler = 'asha',
    # max_resource=max_num_epoch, min_resource=1,
    resources_per_trial={"gpu": num_gpus, "cpu": num_cpus},
    local_dir='logs/',
    num_samples=num_samples,
    time_budget_s=time_budget_s,
    use_ray=True,
)

ray.shutdown()
# Out:
# 2022-12-02 04:30:27,850	WARNING function_runner.py:603 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# Tuning started...
# == Status ==<br>Current time: 2022-12-02 04:30:35 (running for 00:00:07.28)<br>Memory usage on this node: 4.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 1/infinite (1 RUNNING)<br><br>
# (train_distilbert pid=1110) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias']
# (train_distilbert pid=1110) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=1110) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=1110) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias']
# (train_distilbert pid=1110) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=1110) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1110) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=1110)   warnings.warn(
# (train_distilbert pid=1110) ***** Running training *****
# (train_distilbert pid=1110)   Num examples = 1701
# (train_distilbert pid=1110)   Num Epochs = 1
# (train_distilbert pid=1110)   Instantaneous batch size per device = 8
# (train_distilbert pid=1110)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=1110)   Gradient Accumulation steps = 1
# (train_distilbert pid=1110)   Total optimization steps = 213
# (train_distilbert pid=1110)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-02 04:30:40 (running for 00:00:12.36)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:30:45 (running for 00:00:17.37)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:30:50 (running for 00:00:22.37)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:30:55 (running for 00:00:27.38)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:00 (running for 00:00:32.38)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# (train_distilbert pid=1110) {'train_runtime': 25.0235, 'train_samples_per_second': 67.976, 'train_steps_per_second': 8.512, 'train_loss': 0.04155403907310235, 'epoch': 1.0}
# (train_distilbert pid=1110)
# (train_distilbert pid=1110)
# (train_distilbert pid=1110) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=1110)
# (train_distilbert pid=1110)
# (train_distilbert pid=1110) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1110) ***** Running Evaluation *****
# (train_distilbert pid=1110)   Num examples = 1002
# (train_distilbert pid=1110)   Batch size = 8
# == Status ==<br>Current time: 2022-12-02 04:31:05 (running for 00:00:37.39)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# Trial train_distilbert_0c5ec8d0 reported r2=0.04 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}.
# Trial train_distilbert_0c5ec8d0 completed. Last result: r2=0.037139874103649606
# (train_distilbert pid=1110) {'eval_loss': 0.034554753452539444, 'eval_mse': 0.034554753452539444, 'eval_rmse': 0.1858890950679779, 'eval_mae': 0.1528949737548828, 'eval_r2': 0.037139874103649606, 'eval_smape': 31.248000093562872, 'eval_runtime': 4.2961, 'eval_samples_per_second': 233.234, 'eval_steps_per_second': 29.329, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-02 04:31:14 (running for 00:00:46.78)<br>Memory usage on this node: 4.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# (train_distilbert pid=1205) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias']
# (train_distilbert pid=1205) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=1205) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=1205) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'classifier.bias']
# (train_distilbert pid=1205) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=1205) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1205) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=1205)   warnings.warn(
# (train_distilbert pid=1205) ***** Running training *****
# (train_distilbert pid=1205)   Num examples = 1701
# (train_distilbert pid=1205)   Num Epochs = 2
# (train_distilbert pid=1205)   Instantaneous batch size per device = 8
# (train_distilbert pid=1205)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=1205)   Gradient Accumulation steps = 1
# (train_distilbert pid=1205)   Total optimization steps = 308
# (train_distilbert pid=1205)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-02 04:31:19 (running for 00:00:51.78)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:24 (running for 00:00:56.79)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:29 (running for 00:01:01.79)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:34 (running for 00:01:06.80)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:39 (running for 00:01:11.80)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:44 (running for 00:01:16.81)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:31:49 (running for 00:01:21.81)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# (train_distilbert pid=1205) {'train_runtime': 34.0475, 'train_samples_per_second': 72.155, 'train_steps_per_second': 9.046, 'train_loss': 0.03124229319683917, 'epoch': 1.45}
# (train_distilbert pid=1205)
# (train_distilbert pid=1205)
# (train_distilbert pid=1205) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=1205)
# (train_distilbert pid=1205)
# (train_distilbert pid=1205) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1205) ***** Running Evaluation *****
# (train_distilbert pid=1205)   Num examples = 1002
# (train_distilbert pid=1205)   Batch size = 8
# == Status ==<br>Current time: 2022-12-02 04:31:54 (running for 00:01:26.82)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 0c5ec8d0 with r2=0.037139874103649606 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# Trial train_distilbert_10a85884 reported r2=0.19 with parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}.
# Trial train_distilbert_10a85884 completed. Last result: r2=0.18726679500452392
# (train_distilbert pid=1205) {'eval_loss': 0.02916705794632435, 'eval_mse': 0.02916705794632435, 'eval_rmse': 0.1707836538553238, 'eval_mae': 0.13947932422161102, 'eval_r2': 0.18726679500452392, 'eval_smape': 28.776739489770456, 'eval_runtime': 4.2606, 'eval_samples_per_second': 235.176, 'eval_steps_per_second': 29.573, 'epoch': 1.45}
# == Status ==<br>Current time: 2022-12-02 04:32:03 (running for 00:01:35.69)<br>Memory usage on this node: 4.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# (train_distilbert pid=1304) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_layer_norm.weight']
# (train_distilbert pid=1304) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=1304) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=1304) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias']
# (train_distilbert pid=1304) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=1304) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1304) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=1304)   warnings.warn(
# (train_distilbert pid=1304) ***** Running training *****
# (train_distilbert pid=1304)   Num examples = 1701
# (train_distilbert pid=1304)   Num Epochs = 1
# (train_distilbert pid=1304)   Instantaneous batch size per device = 8
# (train_distilbert pid=1304)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=1304)   Gradient Accumulation steps = 1
# (train_distilbert pid=1304)   Total optimization steps = 213
# (train_distilbert pid=1304)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-02 04:32:08 (running for 00:01:40.71)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:32:13 (running for 00:01:45.71)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:32:18 (running for 00:01:50.72)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:32:23 (running for 00:01:55.72)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:32:28 (running for 00:02:00.73)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# (train_distilbert pid=1304)
# (train_distilbert pid=1304)
# (train_distilbert pid=1304) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=1304)
# (train_distilbert pid=1304)
# (train_distilbert pid=1304) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1304) ***** Running Evaluation *****
# (train_distilbert pid=1304)   Num examples = 1002
# (train_distilbert pid=1304)   Batch size = 8
# (train_distilbert pid=1304) {'train_runtime': 23.8673, 'train_samples_per_second': 71.269, 'train_steps_per_second': 8.924, 'train_loss': 0.05091224813685171, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-02 04:32:33 (running for 00:02:05.73)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# Trial train_distilbert_24aefc66 reported r2=0.01 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.489090831567398e-06, 'adam_epsilon': 3.163121807821295e-08, 'adam_beta1': 0.84537379213597, 'adam_beta2': 0.9887505670214453, 'weight_decay': 0.175998257587662}.
# Trial train_distilbert_24aefc66 completed. Last result: r2=0.010822632746843475
# (train_distilbert pid=1304) {'eval_loss': 0.035499218851327896, 'eval_mse': 0.0354992151260376, 'eval_rmse': 0.1884123533964157, 'eval_mae': 0.1554177701473236, 'eval_r2': 0.010822632746843475, 'eval_smape': 31.680022766966065, 'eval_runtime': 4.2597, 'eval_samples_per_second': 235.229, 'eval_steps_per_second': 29.58, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-02 04:32:42 (running for 00:02:14.74)<br>Memory usage on this node: 4.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# (train_distilbert pid=1399) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias']
# (train_distilbert pid=1399) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=1399) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=1399) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# (train_distilbert pid=1399) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=1399) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1399) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=1399)   warnings.warn(
# (train_distilbert pid=1399) ***** Running training *****
# (train_distilbert pid=1399)   Num examples = 1701
# (train_distilbert pid=1399)   Num Epochs = 2
# (train_distilbert pid=1399)   Instantaneous batch size per device = 8
# (train_distilbert pid=1399)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=1399)   Gradient Accumulation steps = 1
# (train_distilbert pid=1399)   Total optimization steps = 218
# (train_distilbert pid=1399)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-02 04:32:47 (running for 00:02:19.74)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:32:52 (running for 00:02:24.75)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:32:57 (running for 00:02:29.75)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:33:02 (running for 00:02:34.76)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:33:07 (running for 00:02:39.76)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# (train_distilbert pid=1399)
# (train_distilbert pid=1399)
# (train_distilbert pid=1399) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=1399)
# (train_distilbert pid=1399)
# (train_distilbert pid=1399) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1399) ***** Running Evaluation *****
# (train_distilbert pid=1399)   Num examples = 1002
# (train_distilbert pid=1399)   Batch size = 8
# (train_distilbert pid=1399) {'train_runtime': 24.4809, 'train_samples_per_second': 70.98, 'train_steps_per_second': 8.905, 'train_loss': 0.03517600593216922, 'epoch': 1.02}
# == Status ==<br>Current time: 2022-12-02 04:33:12 (running for 00:02:44.77)<br>Memory usage on this node: 5.3/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 5/infinite (1 PENDING, 1 RUNNING, 3 TERMINATED)<br><br>
# Trial train_distilbert_41e4cf86 reported r2=0.02 with parameters={'num_train_epochs': 1.021552403070911, 'learning_rate': 1.647430499046145e-06, 'adam_epsilon': 1.2272934289241964e-08, 'adam_beta1': 0.8924937146856989, 'adam_beta2': 0.9858312098115838, 'weight_decay': 0.2772938812342956}.
# Trial train_distilbert_41e4cf86 completed. Last result: r2=0.02477961929278316
# (train_distilbert pid=1399) {'eval_loss': 0.0349983349442482, 'eval_mse': 0.0349983312189579, 'eval_rmse': 0.18707841634750366, 'eval_mae': 0.15451224148273468, 'eval_r2': 0.02477961929278316, 'eval_smape': 31.53005707335329, 'eval_runtime': 4.2569, 'eval_samples_per_second': 235.385, 'eval_steps_per_second': 29.599, 'epoch': 1.02}
# == Status ==<br>Current time: 2022-12-02 04:33:21 (running for 00:02:53.72)<br>Memory usage on this node: 4.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# (train_distilbert pid=1493) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias']
# (train_distilbert pid=1493) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=1493) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=1493) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.weight', 'pre_classifier.bias']
# (train_distilbert pid=1493) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=1493) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1493) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=1493)   warnings.warn(
# (train_distilbert pid=1493) ***** Running training *****
# (train_distilbert pid=1493)   Num examples = 1701
# (train_distilbert pid=1493)   Num Epochs = 1
# (train_distilbert pid=1493)   Instantaneous batch size per device = 8
# (train_distilbert pid=1493)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=1493)   Gradient Accumulation steps = 1
# (train_distilbert pid=1493)   Total optimization steps = 213
# (train_distilbert pid=1493)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-02 04:33:26 (running for 00:02:58.73)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:33:31 (running for 00:03:03.74)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:33:36 (running for 00:03:08.75)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:33:41 (running for 00:03:13.75)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 04:33:46 (running for 00:03:18.76)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# (train_distilbert pid=1493) {'train_runtime': 23.9074, 'train_samples_per_second': 71.149, 'train_steps_per_second': 8.909, 'train_loss': 0.04589774798899189, 'epoch': 1.0}
# (train_distilbert pid=1493)
# (train_distilbert pid=1493)
# (train_distilbert pid=1493) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=1493)
# (train_distilbert pid=1493)
# (train_distilbert pid=1493) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1493) ***** Running Evaluation *****
# (train_distilbert pid=1493)   Num examples = 1002
# (train_distilbert pid=1493)   Batch size = 8
# == Status ==<br>Current time: 2022-12-02 04:33:51 (running for 00:03:23.76)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 6/infinite (1 PENDING, 1 RUNNING, 4 TERMINATED)<br><br>
# Trial train_distilbert_59242c46 reported r2=0.06 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.36325263473191e-06, 'adam_epsilon': 3.8413113126853025e-08, 'adam_beta1': 0.8686254755729765, 'adam_beta2': 0.9857270860586153, 'weight_decay': 0.2796043772067232}.
# Trial train_distilbert_59242c46 completed. Last result: r2=0.056840671586346314
# (train_distilbert pid=1493) {'eval_loss': 0.03384774178266525, 'eval_mse': 0.03384774178266525, 'eval_rmse': 0.18397755920886993, 'eval_mae': 0.15232370793819427, 'eval_r2': 0.056840671586346314, 'eval_smape': 31.128005707335326, 'eval_runtime': 4.2699, 'eval_samples_per_second': 234.664, 'eval_steps_per_second': 29.509, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-02 04:34:00 (running for 00:03:32.80)<br>Memory usage on this node: 4.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# (train_distilbert pid=1587) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_transform.bias']
# (train_distilbert pid=1587) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=1587) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=1587) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight']
# (train_distilbert pid=1587) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=1587) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=1587) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=1587)   warnings.warn(
# (train_distilbert pid=1587) ***** Running training *****
# (train_distilbert pid=1587)   Num examples = 1701
# (train_distilbert pid=1587)   Num Epochs = 2
# (train_distilbert pid=1587)   Instantaneous batch size per device = 8
# (train_distilbert pid=1587)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=1587)   Gradient Accumulation steps = 1
# (train_distilbert pid=1587)   Total optimization steps = 238
# (train_distilbert pid=1587)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-02 04:34:05 (running for 00:03:37.81)<br>Memory usage on this node: 5.4/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: 10a85884 with r2=0.18726679500452392 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.254028596506071e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 7/infinite (1 PENDING, 1 RUNNING, 5 TERMINATED)<br><br>
# ...
# == Status ==<br>Current time: 2022-12-02 05:29:58 (running for 00:59:30.01)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:03 (running for 00:59:35.02)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:08 (running for 00:59:40.03)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:13 (running for 00:59:45.04)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:18 (running for 00:59:50.04)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:23 (running for 00:59:55.05)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:28 (running for 01:00:00.06)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (1 PENDING, 1 RUNNING, 29 TERMINATED)<br><br>
# 2022-12-02 05:30:33,139	INFO stopper.py:363 -- Reached timeout of 3600 seconds. Stopping all trials.
# == Status ==<br>Current time: 2022-12-02 05:30:33 (running for 01:00:05.12)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (31 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-02 05:30:33 (running for 01:00:05.13)<br>Memory usage on this node: 5.5/83.5 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 0/1 GPUs, 0.0/49.64 GiB heap, 0.0/24.82 GiB objects<br>Current best trial: ede1c2f8 with r2=0.48670043794254747 and parameters={'num_train_epochs': 8.323531707299102, 'learning_rate': 1.857295378811325e-05, 'adam_epsilon': 2.4916439803066257e-08, 'adam_beta1': 0.8109062777371857, 'adam_beta2': 0.9870507093459101, 'weight_decay': 0.2851666696787331}<br>Result logdir: /content/logs/train_distilbert_2022-12-02_04-30-27<br>Number of trials: 31/infinite (31 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc             </th><th style="text-align: right;">  adam_beta1</th><th style="text-align: right;">  adam_beta2</th><th style="text-align: right;">  adam_epsilon</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  num_train_epochs</th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">        r2</th></tr>
# </thead>
# <tbody>
# <tr><td>train_distilbert_0c5ec8d0</td><td>TERMINATED</td><td>172.28.0.12:1110</td><td style="text-align: right;">    0.868934</td><td style="text-align: right;">    0.98729 </td><td style="text-align: right;">   1.9703e-08 </td><td style="text-align: right;">    1.56626e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.226646 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         32.8451</td><td style="text-align: right;">0.0371399 </td></tr>
# <tr><td>train_distilbert_10a85884</td><td>TERMINATED</td><td>172.28.0.12:1205</td><td style="text-align: right;">    0.802586</td><td style="text-align: right;">    0.995234</td><td style="text-align: right;">   3.25403e-08</td><td style="text-align: right;">    3.41024e-06</td><td style="text-align: right;">           1.44427</td><td style="text-align: right;">     0.0299459</td><td style="text-align: right;">     1</td><td style="text-align: right;">         41.8021</td><td style="text-align: right;">0.187267  </td></tr>
# <tr><td>train_distilbert_24aefc66</td><td>TERMINATED</td><td>172.28.0.12:1304</td><td style="text-align: right;">    0.845374</td><td style="text-align: right;">    0.988751</td><td style="text-align: right;">   3.16312e-08</td><td style="text-align: right;">    1.48909e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.175998 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         31.6102</td><td style="text-align: right;">0.0108226 </td></tr>
# <tr><td>train_distilbert_41e4cf86</td><td>TERMINATED</td><td>172.28.0.12:1399</td><td style="text-align: right;">    0.892494</td><td style="text-align: right;">    0.985831</td><td style="text-align: right;">   1.22729e-08</td><td style="text-align: right;">    1.64743e-06</td><td style="text-align: right;">           1.02155</td><td style="text-align: right;">     0.277294 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         32.2443</td><td style="text-align: right;">0.0247796 </td></tr>
# <tr><td>train_distilbert_59242c46</td><td>TERMINATED</td><td>172.28.0.12:1493</td><td style="text-align: right;">    0.868625</td><td style="text-align: right;">    0.985727</td><td style="text-align: right;">   3.84131e-08</td><td style="text-align: right;">    1.36325e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.279604 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         31.6326</td><td style="text-align: right;">0.0568407 </td></tr>
# <tr><td>train_distilbert_706258e2</td><td>TERMINATED</td><td>172.28.0.12:1587</td><td style="text-align: right;">    0.869242</td><td style="text-align: right;">    0.988855</td><td style="text-align: right;">   1.01061e-08</td><td style="text-align: right;">    1.7995e-06 </td><td style="text-align: right;">           1.1163 </td><td style="text-align: right;">     0.173688 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         34.4753</td><td style="text-align: right;">0.0423844 </td></tr>
# <tr><td>train_distilbert_87a3b280</td><td>TERMINATED</td><td>172.28.0.12:1683</td><td style="text-align: right;">    0.857986</td><td style="text-align: right;">    0.986129</td><td style="text-align: right;">   5.72013e-08</td><td style="text-align: right;">    1e-06      </td><td style="text-align: right;">           2.30995</td><td style="text-align: right;">     0.289247 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         62.0988</td><td style="text-align: right;">0.0662426 </td></tr>
# <tr><td>train_distilbert_a4310376</td><td>TERMINATED</td><td>172.28.0.12:1791</td><td style="text-align: right;">    0.879265</td><td style="text-align: right;">    0.985325</td><td style="text-align: right;">   2.5796e-08 </td><td style="text-align: right;">    2.02689e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.269961 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         31.7421</td><td style="text-align: right;">0.045148  </td></tr>
# <tr><td>train_distilbert_c9cc61a2</td><td>TERMINATED</td><td>172.28.0.12:1887</td><td style="text-align: right;">    0.841587</td><td style="text-align: right;">    0.985338</td><td style="text-align: right;">   3.73367e-08</td><td style="text-align: right;">    1.02605e-06</td><td style="text-align: right;">           1.45422</td><td style="text-align: right;">     0.237318 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         42.1019</td><td style="text-align: right;">0.0161436 </td></tr>
# <tr><td>train_distilbert_e10cee68</td><td>TERMINATED</td><td>172.28.0.12:1984</td><td style="text-align: right;">    0.874385</td><td style="text-align: right;">    0.986921</td><td style="text-align: right;">   8.76346e-08</td><td style="text-align: right;">    1e-06      </td><td style="text-align: right;">           3.66923</td><td style="text-align: right;">     0.3      </td><td style="text-align: right;">     1</td><td style="text-align: right;">         95.0856</td><td style="text-align: right;">0.0706021 </td></tr>
# <tr><td>train_distilbert_fe415550</td><td>TERMINATED</td><td>172.28.0.12:2101</td><td style="text-align: right;">    0.877629</td><td style="text-align: right;">    0.985014</td><td style="text-align: right;">   8.19811e-08</td><td style="text-align: right;">    1.13828e-06</td><td style="text-align: right;">           1.09663</td><td style="text-align: right;">     0.3      </td><td style="text-align: right;">     1</td><td style="text-align: right;">         33.9266</td><td style="text-align: right;">0.00116266</td></tr>
# <tr><td>train_distilbert_3e8fb034</td><td>TERMINATED</td><td>172.28.0.12:2192</td><td style="text-align: right;">    0.854742</td><td style="text-align: right;">    0.988039</td><td style="text-align: right;">   6.1146e-08 </td><td style="text-align: right;">    1e-06      </td><td style="text-align: right;">           7.72893</td><td style="text-align: right;">     0.274624 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        192.212 </td><td style="text-align: right;">0.334184  </td></tr>
# <tr><td>train_distilbert_57018f5c</td><td>TERMINATED</td><td>172.28.0.12:2334</td><td style="text-align: right;">    0.849321</td><td style="text-align: right;">    0.987524</td><td style="text-align: right;">   5.41635e-08</td><td style="text-align: right;">    1.50645e-06</td><td style="text-align: right;">           6.00307</td><td style="text-align: right;">     0.3      </td><td style="text-align: right;">     1</td><td
# (train_distilbert pid=4416) Saving model checkpoint to ./checkpoint-1000
# (train_distilbert pid=4416) Configuration saved in ./checkpoint-1000/config.json
# (train_distilbert pid=4416) Model weights saved in ./checkpoint-1000/pytorch_model.bin
# (train_distilbert pid=4416) tokenizer config file saved in ./checkpoint-1000/tokenizer_config.json
# (train_distilbert pid=4416) Special tokens file saved in ./checkpoint-1000/special_tokens_map.json
# (train_distilbert pid=4416) {'train_runtime': 166.0707, 'train_samples_per_second': 71.844, 'train_steps_per_second': 9.002, 'train_loss': 0.011085732246322377, 'epoch': 7.02}
# (train_distilbert pid=4416)
# (train_distilbert pid=4416)
# (train_distilbert pid=4416) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=4416)
# (train_distilbert pid=4416)
# (train_distilbert pid=4416) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=4416) ***** Running Evaluation *****
# (train_distilbert pid=4416)   Num examples = 1002
# (train_distilbert pid=4416)   Batch size = 8
# 2022-12-02 05:31:46,869	INFO tune.py:747 -- Total run time: 3679.02 seconds (3605.12 seconds for the tuning loop).
# (train_distilbert pid=4416) {'eval_loss': 0.019225232303142548, 'eval_mse': 0.019225232303142548, 'eval_rmse': 0.13865508139133453, 'eval_mae': 0.11000686138868332, 'eval_r2': 0.4642933742508213, 'eval_smape': 23.33022626621756, 'eval_runtime': 4.2487, 'eval_samples_per_second': 235.839, 'eval_steps_per_second': 29.656, 'epoch': 7.02}

# %%
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_steps=20000,
                                  #per_device_train_batch_size=64,
                                  #per_device_eval_batch_size=20,
                                  learning_rate = 1.857295378811325e-05,
                                  adam_epsilon = 2.4916439803066257e-08,
                                  adam_beta1 = 0.8109062777371857,
                                  adam_beta2 = 0.9870507093459101,
                                  weight_decay = 0.2851666696787331,
                                  num_train_epochs=50,
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics_for_regression
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1701
#   Num Epochs = 50
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10650
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='10650' max='10650' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10650/10650 20:21, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to test_trainer/checkpoint-500
# Configuration saved in test_trainer/checkpoint-500/config.json
# Model weights saved in test_trainer/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-1000
# Configuration saved in test_trainer/checkpoint-1000/config.json
# Model weights saved in test_trainer/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-1500
# Configuration saved in test_trainer/checkpoint-1500/config.json
# Model weights saved in test_trainer/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-2000
# Configuration saved in test_trainer/checkpoint-2000/config.json
# Model weights saved in test_trainer/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-2500
# Configuration saved in test_trainer/checkpoint-2500/config.json
# Model weights saved in test_trainer/checkpoint-2500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-3000
# Configuration saved in test_trainer/checkpoint-3000/config.json
# Model weights saved in test_trainer/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-3500
# Configuration saved in test_trainer/checkpoint-3500/config.json
# Model weights saved in test_trainer/checkpoint-3500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-4000
# Configuration saved in test_trainer/checkpoint-4000/config.json
# Model weights saved in test_trainer/checkpoint-4000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-4500
# Configuration saved in test_trainer/checkpoint-4500/config.json
# Model weights saved in test_trainer/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-5000
# Configuration saved in test_trainer/checkpoint-5000/config.json
# Model weights saved in test_trainer/checkpoint-5000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-5500
# Configuration saved in test_trainer/checkpoint-5500/config.json
# Model weights saved in test_trainer/checkpoint-5500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-6000
# Configuration saved in test_trainer/checkpoint-6000/config.json
# Model weights saved in test_trainer/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-6500
# Configuration saved in test_trainer/checkpoint-6500/config.json
# Model weights saved in test_trainer/checkpoint-6500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-7000
# Configuration saved in test_trainer/checkpoint-7000/config.json
# Model weights saved in test_trainer/checkpoint-7000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-7500
# Configuration saved in test_trainer/checkpoint-7500/config.json
# Model weights saved in test_trainer/checkpoint-7500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-8000
# Configuration saved in test_trainer/checkpoint-8000/config.json
# Model weights saved in test_trainer/checkpoint-8000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-8500
# Configuration saved in test_trainer/checkpoint-8500/config.json
# Model weights saved in test_trainer/checkpoint-8500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-9000
# Configuration saved in test_trainer/checkpoint-9000/config.json
# Model weights saved in test_trainer/checkpoint-9000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-9500
# Configuration saved in test_trainer/checkpoint-9500/config.json
# Model weights saved in test_trainer/checkpoint-9500/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-10000
# Configuration saved in test_trainer/checkpoint-10000/config.json
# Model weights saved in test_trainer/checkpoint-10000/pytorch_model.bin
# Saving model checkpoint to test_trainer/checkpoint-10500
# Configuration saved in test_trainer/checkpoint-10500/config.json
# Model weights saved in test_trainer/checkpoint-10500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=10650, training_loss=0.0027950387157744646, metrics={'train_runtime': 1224.5335, 'train_samples_per_second': 69.455, 'train_steps_per_second': 8.697, 'total_flos': 1.12661513362944e+16, 'train_loss': 0.0027950387157744646, 'epoch': 50.0})

# %%
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 8
#     <div>
#
#       <progress value='126' max='126' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [126/126 00:04]
#     </div>
# {'eval_loss': 0.018708493560552597,
#  'eval_mse': 0.018708493560552597,
#  'eval_rmse': 0.13677899539470673,
#  'eval_mae': 0.10913343727588654,
#  'eval_r2': 0.47869219056724877,
#  'eval_smape': 23.115403957709578,
#  'eval_runtime': 4.4244,
#  'eval_samples_per_second': 226.471,
#  'eval_steps_per_second': 28.478,
#  'epoch': 50.0}

# %% [markdown]
# # Another Ray search and the Seventh Model

# %%
#New function to evaluate, now it includes the Person r 
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    rmse = mean_squared_error(labels, predictions, squared=False)
    r, p = scipy.stats.pearsonr(labels, predictions)
    r = r.item()
    return {"rmse": rmse, "pearsonr": r}

# %%
#Download the pre-trained model
model = AutoModelForSequenceClassification.from_pretrained(MODEL_CHECKPOINT, num_labels=1)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.25.1",
#   "vocab_size": 30522
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--distilbert-base-uncased/snapshots/1c4513b2eedbda136f57676a34eea67aba266e5c/pytorch_model.bin
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#Re-size to the length of the tokenizer 
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30522, 768, padding_idx=0)

# %%
#Arguments for training 
args = TrainingArguments(
    output_dir='output',
    do_eval=True,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#Define the trainer 
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# %%
#Train the model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1446
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 543
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='543' max='543' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [543/543 03:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.014800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to output/checkpoint-500
# Configuration saved in output/checkpoint-500/config.json
# Model weights saved in output/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in output/checkpoint-500/tokenizer_config.json
# Special tokens file saved in output/checkpoint-500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=543, training_loss=0.014244305549625094, metrics={'train_runtime': 216.7375, 'train_samples_per_second': 20.015, 'train_steps_per_second': 2.505, 'total_flos': 574633327417344.0, 'train_loss': 0.014244305549625094, 'epoch': 3.0})

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 255
#   Batch size = 8
#     <div>
#
#       <progress value='32' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:04]
#     </div>
# {'eval_loss': 0.01071194838732481,
#  'eval_rmse': 0.10349854826927185,
#  'eval_pearsonr': 0.78164069617914,
#  'eval_runtime': 4.5533,
#  'eval_samples_per_second': 56.003,
#  'eval_steps_per_second': 7.028,
#  'epoch': 3.0}

# %%
# !pip install flaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flaml in /usr/local/lib/python3.8/dist-packages (1.0.14)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.3.5)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from flaml) (3.3.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.0.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.7.3)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.8/dist-packages (from flaml) (1.21.6)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.8/dist-packages (from flaml) (0.90)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from lightgbm>=2.3.1->flaml) (0.38.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->flaml) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.4->flaml) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->flaml) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->flaml) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.24->flaml) (1.2.0)

# %%
import flaml

# %%
MODEL_CHECKPOINT = "distilbert-base-uncased"

# %%
def train_distilbert(config: dict):

    

    train_dataset, eval_dataset = tokenized_train_dataset, tokenized_val_dataset

    model = AutoModelForSequenceClassification.from_pretrained(
        MODEL_CHECKPOINT, num_labels=1
    )

    model.resize_token_embeddings(len(tokenizer))

    def compute_metrics(eval_pred):

      predictions, labels = eval_pred
      rmse = mean_squared_error(labels, predictions, squared=False)
      r, p = scipy.stats.pearsonr(labels, predictions)
      r = r.item()
      return {"rmse": rmse, "pearsonr": r}


    training_args = TrainingArguments(
        output_dir='.',
        do_eval=False,
        disable_tqdm=True,
        logging_steps=20000,
        save_total_limit=0,
        **config,
    )

    trainer = Trainer(
        model,
        training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        compute_metrics=compute_metrics,
    )

    # train model
    trainer.train()

    # evaluate model
    eval_output = trainer.evaluate()

    # report the metric to optimize
    flaml.tune.report(
        pearsonr=eval_output["eval_pearsonr"],
    )

# %%
############ Version 2 ########################
#New search space for the hyperparameters to optimize 

max_num_epoch = 64
search_space = {
        # You can mix constants with search space objects.
        "num_train_epochs": flaml.tune.loguniform(1, max_num_epoch),
        "learning_rate": flaml.tune.loguniform(1e-6, 1e-4),
        "adam_epsilon": flaml.tune.loguniform(1e-9, 1e-7),
        "adam_beta1": flaml.tune.uniform(0.8, 0.99),
        "adam_beta2": flaml.tune.loguniform(98e-2, 9999e-4),
        "weight_decay": flaml.tune.uniform(0.0, 0.3),
        
}

# %%
# optimization objective
HP_METRIC, MODE = "pearsonr", "max"

# resources
num_cpus = 0
num_gpus = 1

# constraints
num_samples = -1    # number of trials, -1 means unlimited
time_budget_s = 3600    # time budget in seconds

# %%
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.8/dist-packages (0.0.11)

# %%
import pickle5 as pickle

# %%
#Another ray tuning 
import time
import ray
start_time = time.time()
ray.shutdown()
ray.init(num_cpus=num_cpus, num_gpus=num_gpus)

print("Tuning started...")
analysis = flaml.tune.run(
    train_distilbert,
    search_alg=flaml.CFO(
        space=search_space,
        metric=HP_METRIC,
        mode=MODE,
        low_cost_partial_config={"num_train_epochs": 1}),
    # uncomment the following if scheduler = 'asha',
    # max_resource=max_num_epoch, min_resource=1,
    resources_per_trial={"gpu": num_gpus, "cpu": num_cpus},
    local_dir='logs/',
    num_samples=num_samples,
    time_budget_s=time_budget_s,
    use_ray=True,
)

ray.shutdown()
# Out:
# 2022-12-04 02:36:33,735	WARNING function_runner.py:603 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# Tuning started...
# == Status ==<br>Current time: 2022-12-04 02:36:41 (running for 00:00:07.92)<br>Memory usage on this node: 3.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 1/infinite (1 RUNNING)<br><br>
# (train_distilbert pid=2464) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.bias']
# (train_distilbert pid=2464) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=2464) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=2464) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias']
# (train_distilbert pid=2464) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=2464) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=2464) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=2464)   warnings.warn(
# (train_distilbert pid=2464) ***** Running training *****
# (train_distilbert pid=2464)   Num examples = 1446
# (train_distilbert pid=2464)   Num Epochs = 1
# (train_distilbert pid=2464)   Instantaneous batch size per device = 8
# (train_distilbert pid=2464)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=2464)   Gradient Accumulation steps = 1
# (train_distilbert pid=2464)   Total optimization steps = 181
# (train_distilbert pid=2464)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-04 02:36:46 (running for 00:00:12.99)<br>Memory usage on this node: 4.7/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:36:51 (running for 00:00:18.00)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:36:57 (running for 00:00:23.01)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:02 (running for 00:00:28.02)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:07 (running for 00:00:33.02)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:12 (running for 00:00:38.03)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:17 (running for 00:00:43.04)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:22 (running for 00:00:48.05)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:27 (running for 00:00:53.06)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:32 (running for 00:00:58.07)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:37 (running for 00:01:03.09)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:42 (running for 00:01:08.10)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:47 (running for 00:01:13.11)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:52 (running for 00:01:18.12)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:37:57 (running for 00:01:23.12)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# (train_distilbert pid=2464) {'train_runtime': 74.6131, 'train_samples_per_second': 19.38, 'train_steps_per_second': 2.426, 'train_loss': 0.08657695707036646, 'epoch': 1.0}
# (train_distilbert pid=2464)
# (train_distilbert pid=2464)
# (train_distilbert pid=2464) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=2464)
# (train_distilbert pid=2464)
# (train_distilbert pid=2464) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=2464) ***** Running Evaluation *****
# (train_distilbert pid=2464)   Num examples = 255
# (train_distilbert pid=2464)   Batch size = 8
# == Status ==<br>Current time: 2022-12-04 02:38:02 (running for 00:01:28.13)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 2/infinite (1 PENDING, 1 RUNNING)<br><br>
# Trial train_distilbert_77cd135a reported pearsonr=0.28 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}.
# Trial train_distilbert_77cd135a completed. Last result: pearsonr=0.28123629088139435
# (train_distilbert pid=2464) {'eval_loss': 0.02464824542403221, 'eval_rmse': 0.15699759125709534, 'eval_pearsonr': 0.28123629088139435, 'eval_runtime': 4.5185, 'eval_samples_per_second': 56.435, 'eval_steps_per_second': 7.082, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-04 02:38:12 (running for 00:01:38.24)<br>Memory usage on this node: 4.3/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# (train_distilbert pid=2578) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# (train_distilbert pid=2578) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=2578) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=2578) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'classifier.weight', 'pre_classifier.weight']
# (train_distilbert pid=2578) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=2578) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=2578) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=2578)   warnings.warn(
# (train_distilbert pid=2578) ***** Running training *****
# (train_distilbert pid=2578)   Num examples = 1446
# (train_distilbert pid=2578)   Num Epochs = 2
# (train_distilbert pid=2578)   Instantaneous batch size per device = 8
# (train_distilbert pid=2578)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=2578)   Gradient Accumulation steps = 1
# (train_distilbert pid=2578)   Total optimization steps = 262
# (train_distilbert pid=2578)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-04 02:38:17 (running for 00:01:43.25)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:22 (running for 00:01:48.26)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:27 (running for 00:01:53.27)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:32 (running for 00:01:58.29)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:37 (running for 00:02:03.30)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:42 (running for 00:02:08.31)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:47 (running for 00:02:13.32)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:52 (running for 00:02:18.33)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:38:57 (running for 00:02:23.34)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:02 (running for 00:02:28.35)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:07 (running for 00:02:33.36)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:12 (running for 00:02:38.37)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:17 (running for 00:02:43.39)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:22 (running for 00:02:48.39)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:27 (running for 00:02:53.40)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:32 (running for 00:02:58.41)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:37 (running for 00:03:03.43)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:42 (running for 00:03:08.44)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:47 (running for 00:03:13.44)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:52 (running for 00:03:18.45)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:39:57 (running for 00:03:23.47)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# (train_distilbert pid=2578) {'train_runtime': 104.3841, 'train_samples_per_second': 20.007, 'train_steps_per_second': 2.51, 'train_loss': 0.045996258277019475, 'epoch': 1.45}
# (train_distilbert pid=2578)
# (train_distilbert pid=2578)
# (train_distilbert pid=2578) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=2578)
# (train_distilbert pid=2578)
# (train_distilbert pid=2578) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=2578) ***** Running Evaluation *****
# (train_distilbert pid=2578)   Num examples = 255
# (train_distilbert pid=2578)   Batch size = 8
# == Status ==<br>Current time: 2022-12-04 02:40:02 (running for 00:03:28.47)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 77cd135a with pearsonr=0.28123629088139435 and parameters={'num_train_epochs': 1.0, 'learning_rate': 1.5662610420278344e-06, 'adam_epsilon': 1.9702991167906198e-08, 'adam_beta1': 0.8689337534108345, 'adam_beta2': 0.9872898093714128, 'weight_decay': 0.22664606941097878}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 3/infinite (1 PENDING, 1 RUNNING, 1 TERMINATED)<br><br>
# Trial train_distilbert_7c710ec0 reported pearsonr=0.53 with parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}.
# (train_distilbert pid=2578) {'eval_loss': 0.01961401104927063, 'eval_rmse': 0.1400500237941742, 'eval_pearsonr': 0.5345884227276733, 'eval_runtime': 4.6194, 'eval_samples_per_second': 55.202, 'eval_steps_per_second': 6.927, 'epoch': 1.45}
# Trial train_distilbert_7c710ec0 completed. Last result: pearsonr=0.5345884227276733
# == Status ==<br>Current time: 2022-12-04 02:40:12 (running for 00:03:38.15)<br>Memory usage on this node: 4.3/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# (train_distilbert pid=2702) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias']
# (train_distilbert pid=2702) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=2702) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=2702) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias']
# (train_distilbert pid=2702) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=2702) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=2702) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=2702)   warnings.warn(
# (train_distilbert pid=2702) ***** Running training *****
# (train_distilbert pid=2702)   Num examples = 1446
# (train_distilbert pid=2702)   Num Epochs = 1
# (train_distilbert pid=2702)   Instantaneous batch size per device = 8
# (train_distilbert pid=2702)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=2702)   Gradient Accumulation steps = 1
# (train_distilbert pid=2702)   Total optimization steps = 181
# (train_distilbert pid=2702)   Number of trainable parameters = 66954241
# == Status ==<br>Current time: 2022-12-04 02:40:17 (running for 00:03:43.16)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:22 (running for 00:03:48.17)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:27 (running for 00:03:53.19)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:32 (running for 00:03:58.20)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:37 (running for 00:04:03.21)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:42 (running for 00:04:08.23)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:47 (running for 00:04:13.24)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:52 (running for 00:04:18.25)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:40:57 (running for 00:04:23.26)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:41:02 (running for 00:04:28.27)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:41:07 (running for 00:04:33.28)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:41:12 (running for 00:04:38.29)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:41:17 (running for 00:04:43.30)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:41:22 (running for 00:04:48.31)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 02:41:27 (running for 00:04:53.33)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# (train_distilbert pid=2702)
# (train_distilbert pid=2702)
# (train_distilbert pid=2702) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=2702)
# (train_distilbert pid=2702)
# (train_distilbert pid=2702) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=2702) ***** Running Evaluation *****
# (train_distilbert pid=2702)   Num examples = 255
# (train_distilbert pid=2702)   Batch size = 8
# (train_distilbert pid=2702) {'train_runtime': 72.4458, 'train_samples_per_second': 19.96, 'train_steps_per_second': 2.498, 'train_loss': 0.06319442770099112, 'epoch': 1.0}
# == Status ==<br>Current time: 2022-12-04 02:41:32 (running for 00:04:58.34)<br>Memory usage on this node: 5.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 7c710ec0 with pearsonr=0.5345884227276733 and parameters={'num_train_epochs': 1.444265389543504, 'learning_rate': 3.4102391893542776e-06, 'adam_epsilon': 3.2540285965060775e-08, 'adam_beta1': 0.8025861976630991, 'adam_beta2': 0.9952338248324752, 'weight_decay': 0.029945923065410704}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 4/infinite (1 PENDING, 1 RUNNING, 2 TERMINATED)<br><br>
# Trial train_distilbert_aec07e42 reported pearsonr=0.32 with parameters={'num_train_epochs': 1.0, 'learning_rate': 1.489090831567398e-06, 'adam_epsilon': 3.163121807821293e-08, 'adam_beta1': 0.84537379213597, 'adam_beta2': 0.9887505670214453, 'weight_decay': 0.175998257587662}.
# Trial train_distilbert_aec07e42 completed. Last result: pearsonr=0.3235139991500585
# (train_distilbert pid=2702) {'eval_loss': 0.023653998970985413, 'eval_rmse': 0.15379856526851654, 'eval_pearsonr': 0.3235139991500585, 'eval_runtime': 4.5118, 'eval_samples_per_second': 56.518, 'eval_steps_per_second': 7.092, 'epoch': 1.0}
# ...
# == Status ==<br>Current time: 2022-12-04 03:36:27 (running for 00:59:53.21)<br>Memory usage on this node: 5.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 051bcff8 with pearsonr=0.7775081354838481 and parameters={'num_train_epochs': 1.3754030919162836, 'learning_rate': 5.166521304410478e-05, 'adam_epsilon': 6.837013226375621e-08, 'adam_beta1': 0.8, 'adam_beta2': 0.9858580464571414, 'weight_decay': 0.2680545279738851}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 32/infinite (1 PENDING, 1 RUNNING, 30 TERMINATED)<br><br>
# (train_distilbert pid=5713) {'train_runtime': 153.2092, 'train_samples_per_second': 20.111, 'train_steps_per_second': 2.519, 'train_loss': 0.016399888794656863, 'epoch': 2.13}
# (train_distilbert pid=5713)
# (train_distilbert pid=5713)
# (train_distilbert pid=5713) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=5713)
# (train_distilbert pid=5713)
# (train_distilbert pid=5713) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=5713) ***** Running Evaluation *****
# (train_distilbert pid=5713)   Num examples = 255
# (train_distilbert pid=5713)   Batch size = 8
# == Status ==<br>Current time: 2022-12-04 03:36:32 (running for 00:59:58.24)<br>Memory usage on this node: 5.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 1.0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 051bcff8 with pearsonr=0.7775081354838481 and parameters={'num_train_epochs': 1.3754030919162836, 'learning_rate': 5.166521304410478e-05, 'adam_epsilon': 6.837013226375621e-08, 'adam_beta1': 0.8, 'adam_beta2': 0.9858580464571414, 'weight_decay': 0.2680545279738851}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 32/infinite (1 PENDING, 1 RUNNING, 30 TERMINATED)<br><br>
# Trial train_distilbert_39980b5a reported pearsonr=0.78 with parameters={'num_train_epochs': 2.130842500279904, 'learning_rate': 7.191707204279362e-05, 'adam_epsilon': 1e-07, 'adam_beta1': 0.8148103444617636, 'adam_beta2': 0.986557241529914, 'weight_decay': 0.23585877049061496}.
# Trial train_distilbert_39980b5a completed. Last result: pearsonr=0.780701630425316
# (train_distilbert pid=5713) {'eval_loss': 0.011654267087578773, 'eval_rmse': 0.10795493423938751, 'eval_pearsonr': 0.780701630425316, 'eval_runtime': 4.5492, 'eval_samples_per_second': 56.054, 'eval_steps_per_second': 7.034, 'epoch': 2.13}
# 2022-12-04 03:36:39,158	INFO stopper.py:363 -- Reached timeout of 3600 seconds. Stopping all trials.
# == Status ==<br>Current time: 2022-12-04 03:36:40 (running for 01:00:06.00)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 39980b5a with pearsonr=0.780701630425316 and parameters={'num_train_epochs': 2.130842500279904, 'learning_rate': 7.191707204279362e-05, 'adam_epsilon': 1e-07, 'adam_beta1': 0.8148103444617636, 'adam_beta2': 0.986557241529914, 'weight_decay': 0.23585877049061496}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 33/infinite (33 TERMINATED)<br><br>
# == Status ==<br>Current time: 2022-12-04 03:36:40 (running for 01:00:06.06)<br>Memory usage on this node: 5.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/0 CPUs, 0/1 GPUs, 0.0/7.14 GiB heap, 0.0/3.57 GiB objects (0.0/1.0 accelerator_type:T4)<br>Current best trial: 39980b5a with pearsonr=0.780701630425316 and parameters={'num_train_epochs': 2.130842500279904, 'learning_rate': 7.191707204279362e-05, 'adam_epsilon': 1e-07, 'adam_beta1': 0.8148103444617636, 'adam_beta2': 0.986557241529914, 'weight_decay': 0.23585877049061496}<br>Result logdir: /content/logs/train_distilbert_2022-12-04_02-36-33<br>Number of trials: 33/infinite (33 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name               </th><th>status    </th><th>loc             </th><th style="text-align: right;">  adam_beta1</th><th style="text-align: right;">  adam_beta2</th><th style="text-align: right;">  adam_epsilon</th><th style="text-align: right;">  learning_rate</th><th style="text-align: right;">  num_train_epochs</th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  pearsonr</th></tr>
# </thead>
# <tbody>
# <tr><td>train_distilbert_77cd135a</td><td>TERMINATED</td><td>172.28.0.12:2464</td><td style="text-align: right;">    0.868934</td><td style="text-align: right;">    0.98729 </td><td style="text-align: right;">   1.9703e-08 </td><td style="text-align: right;">    1.56626e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.226646 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         82.8108</td><td style="text-align: right;">  0.281236</td></tr>
# <tr><td>train_distilbert_7c710ec0</td><td>TERMINATED</td><td>172.28.0.12:2578</td><td style="text-align: right;">    0.802586</td><td style="text-align: right;">    0.995234</td><td style="text-align: right;">   3.25403e-08</td><td style="text-align: right;">    3.41024e-06</td><td style="text-align: right;">           1.44427</td><td style="text-align: right;">     0.0299459</td><td style="text-align: right;">     1</td><td style="text-align: right;">        112.5   </td><td style="text-align: right;">  0.534588</td></tr>
# <tr><td>train_distilbert_aec07e42</td><td>TERMINATED</td><td>172.28.0.12:2702</td><td style="text-align: right;">    0.845374</td><td style="text-align: right;">    0.988751</td><td style="text-align: right;">   3.16312e-08</td><td style="text-align: right;">    1.48909e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.175998 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         80.4575</td><td style="text-align: right;">  0.323514</td></tr>
# <tr><td>train_distilbert_f648e20e</td><td>TERMINATED</td><td>172.28.0.12:2814</td><td style="text-align: right;">    0.892494</td><td style="text-align: right;">    0.985831</td><td style="text-align: right;">   1.22729e-08</td><td style="text-align: right;">    1.64743e-06</td><td style="text-align: right;">           1.02155</td><td style="text-align: right;">     0.277294 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         81.9792</td><td style="text-align: right;">  0.298422</td></tr>
# <tr><td>train_distilbert_2a2cfccc</td><td>TERMINATED</td><td>172.28.0.12:2924</td><td style="text-align: right;">    0.845066</td><td style="text-align: right;">    0.987186</td><td style="text-align: right;">   6.16685e-08</td><td style="text-align: right;">    1.29608e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.228957 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         80.3606</td><td style="text-align: right;">  0.470215</td></tr>
# <tr><td>train_distilbert_5f35023e</td><td>TERMINATED</td><td>172.28.0.12:3036</td><td style="text-align: right;">    0.845682</td><td style="text-align: right;">    0.990318</td><td style="text-align: right;">   1.62244e-08</td><td style="text-align: right;">    1.71084e-06</td><td style="text-align: right;">           1.1163 </td><td style="text-align: right;">     0.12304  </td><td style="text-align: right;">     1</td><td style="text-align: right;">         90.1372</td><td style="text-align: right;">  0.338453</td></tr>
# <tr><td>train_distilbert_93139d68</td><td>TERMINATED</td><td>172.28.0.12:3144</td><td style="text-align: right;">    0.834426</td><td style="text-align: right;">    0.987588</td><td style="text-align: right;">   9.18311e-08</td><td style="text-align: right;">    1e-06      </td><td style="text-align: right;">           2.30995</td><td style="text-align: right;">     0.2386   </td><td style="text-align: right;">     1</td><td style="text-align: right;">        174.53  </td><td style="text-align: right;">  0.4316  </td></tr>
# <tr><td>train_distilbert_d064b9d6</td><td>TERMINATED</td><td>172.28.0.12:3263</td><td style="text-align: right;">    0.855705</td><td style="text-align: right;">    0.986783</td><td style="text-align: right;">   4.1413e-08 </td><td style="text-align: right;">    1.92702e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.219314 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         81.1941</td><td style="text-align: right;">  0.352282</td></tr>
# <tr><td>train_distilbert_3cde6616</td><td>TERMINATED</td><td>172.28.0.12:3357</td><td style="text-align: right;">    0.828666</td><td style="text-align: right;">    0.986393</td><td style="text-align: right;">   4.02525e-08</td><td style="text-align: right;">    1.32984e-06</td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.177027 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         80.4917</td><td style="text-align: right;">  0.138756</td></tr>
# <tr><td>train_distilbert_6dd4014a</td><td>TERMINATED</td><td>172.28.0.12:3450</td><td style="text-align: right;">    0.861465</td><td style="text-align: right;">    0.987978</td><td style="text-align: right;">   9.44785e-08</td><td style="text-align: right;">    1.26318e-06</td><td style="text-align: right;">           1.58844</td><td style="text-align: right;">     0.280886 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        122.462 </td><td style="text-align: right;">  0.422607</td></tr>
# <tr><td>train_distilbert_a24cd302</td><td>TERMINATED</td><td>172.28.0.12:3556</td><td style="text-align: right;">    0.864709</td><td style="text-align: right;">    0.986069</td><td style="text-align: right;">   8.83834e-08</td><td style="text-align: right;">    1.4753e-06 </td><td style="text-align: right;">           1      </td><td style="text-align: right;">     0.254332 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         80.4185</td><td style="text-align: right;">  0.32935 </td></tr>
# <tr><td>train_distilbert_efcb85f6</td><td>TERMINATED</td><td>172.28.0.12:3650</td><td style="text-align: right;">    0.825422</td><td style="text-align: right;">    0.988303</td><td style="text-align: right;">   4.30285e-08</td><td style="text-align: right;">    1.13864e-06</td><td style="text-align: right;">           2.10642</td><td style="text-align: right;">     0.203581 </td><td style="text-align: right;">     1</td><td style="text-align: right;">        159.91  </td><td style="text-align: right;">  0.381812</td></tr>
# <tr><td>train_distilbert_23b87ee6</td><td>TERMINATED</td><td>172.28.0.12:3775</td><td style="text-align: right;">    0.820001</td><td style="text-align: right;">    0.987789</td><td style="text-align: right;">   3.81148e-08</td><td style="text-align: right;">    1.95249e-06</td><td style="text-align: right;">           1.63606</td><td style="text-align: right;">     0.257143 </td><td style="text-align: right;">
# (train_distilbert pid=5828) Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight']
# (train_distilbert pid=5828) - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# (train_distilbert pid=5828) - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# (train_distilbert pid=5828) Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias', 'classifier.weight']
# (train_distilbert pid=5828) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (train_distilbert pid=5828) The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=5828) /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
# (train_distilbert pid=5828)   warnings.warn(
# (train_distilbert pid=5828) ***** Running training *****
# (train_distilbert pid=5828)   Num examples = 1446
# (train_distilbert pid=5828)   Num Epochs = 1
# (train_distilbert pid=5828)   Instantaneous batch size per device = 8
# (train_distilbert pid=5828)   Total train batch size (w. parallel, distributed & accumulation) = 8
# (train_distilbert pid=5828)   Gradient Accumulation steps = 1
# (train_distilbert pid=5828)   Total optimization steps = 181
# (train_distilbert pid=5828)   Number of trainable parameters = 66954241
# (train_distilbert pid=5828)
# (train_distilbert pid=5828)
# (train_distilbert pid=5828) Training completed. Do not forget to share your model on huggingface.co/models =)
# (train_distilbert pid=5828)
# (train_distilbert pid=5828)
# (train_distilbert pid=5828) The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# (train_distilbert pid=5828) ***** Running Evaluation *****
# (train_distilbert pid=5828)   Num examples = 255
# (train_distilbert pid=5828)   Batch size = 8
# (train_distilbert pid=5828) {'train_runtime': 73.5021, 'train_samples_per_second': 19.673, 'train_steps_per_second': 2.463, 'train_loss': 0.022954408635092044, 'epoch': 1.0}
# 2022-12-04 03:38:02,516	INFO tune.py:747 -- Total run time: 3688.79 seconds (3606.01 seconds for the tuning loop).
# (train_distilbert pid=5828) {'eval_loss': 0.011115641333162785, 'eval_rmse': 0.10543074458837509, 'eval_pearsonr': 0.7644832697747332, 'eval_runtime': 4.5028, 'eval_samples_per_second': 56.631, 'eval_steps_per_second': 7.107, 'epoch': 1.0}

# %%
#Apply the best hyperparameters 
training_args = TrainingArguments(output_dir="test_trainer",
                                  logging_steps=20000,
                                  #per_device_train_batch_size=64,
                                  #per_device_eval_batch_size=20,
                                  learning_rate = 7.191707204279362e-05,
                                  adam_epsilon = 1e-07,
                                  adam_beta1 = 0.8148103444617636,
                                  adam_beta2 = 0.986557241529914,
                                  weight_decay = 0.23585877049061496,
                                  num_train_epochs=3,
                                  )
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_val_dataset,
    compute_metrics=compute_metrics
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
#Train the model
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1446
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 543
#   Number of trainable parameters = 66954241
#     <div>
#
#       <progress value='543' max='543' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [543/543 03:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to test_trainer/checkpoint-500
# Configuration saved in test_trainer/checkpoint-500/config.json
# Model weights saved in test_trainer/checkpoint-500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=543, training_loss=0.0134967598467242, metrics={'train_runtime': 212.8491, 'train_samples_per_second': 20.381, 'train_steps_per_second': 2.551, 'total_flos': 574633327417344.0, 'train_loss': 0.0134967598467242, 'epoch': 3.0})

# %%
#Evaluate the model
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 255
#   Batch size = 8
#     <div>
#
#       <progress value='32' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:03]
#     </div>
# {'eval_loss': 0.01217750832438469,
#  'eval_rmse': 0.11035174876451492,
#  'eval_pearsonr': 0.7761107852886949,
#  'eval_runtime': 4.1049,
#  'eval_samples_per_second': 62.12,
#  'eval_steps_per_second': 7.796,
#  'epoch': 3.0}

# %% [markdown]
# # Testing the Final Model on the test dataset

# %%
trainer.save_model("distilbert_classification")
# Out:
# Saving model checkpoint to distilbert_classification
# Configuration saved in distilbert_classification/config.json
# Model weights saved in distilbert_classification/pytorch_model.bin

# %%
predictions = trainer.predict(tokenized_test_dataset)
# Out:
# The following columns in the test set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1002
#   Batch size = 8

# %%
type(predictions)
# Out:
# transformers.trainer_utils.PredictionOutput

# %%
predictions[0]
# Out:
# array([[0.53839153],
#        [0.45939144],
#        [0.45762992],
#        ...,
#        [0.46221837],
#        [0.7500934 ],
#        [0.52689624]], dtype=float32)

# %%
predictions[1]
# Out:
# array([0.734, 0.422, 0.663, ..., 0.424, 0.597, 0.547], dtype=float32)

# %%
predictions[2]
# Out:
# {'test_loss': 0.015755170956254005,
#  'test_rmse': 0.12551960349082947,
#  'test_pearsonr': 0.7619375508507787,
#  'test_runtime': 16.4978,
#  'test_samples_per_second': 60.735,
#  'test_steps_per_second': 7.637}

# %%
trainer.eval_dataset=tokenized_test_dataset

# %%
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1002
#   Batch size = 8
#     <div>
#
#       <progress value='126' max='126' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [126/126 00:16]
#     </div>
# {'eval_loss': 0.015755170956254005,
#  'eval_rmse': 0.12551960349082947,
#  'eval_pearsonr': 0.7619375508507787,
#  'eval_runtime': 16.2302,
#  'eval_samples_per_second': 61.737,
#  'eval_steps_per_second': 7.763,
#  'epoch': 3.0}
